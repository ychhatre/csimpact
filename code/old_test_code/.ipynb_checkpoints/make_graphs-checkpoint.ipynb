# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import time
import os

# %%
from plotly.graph_objs import Bar, Layout
from plotly import offline
import plotly.express as px
import plotly.graph_objects as go

# %%
colleges = pd.read_csv('/Users/kevins/Documents/CSImpact/data/colleges.csv')

# %%
data = pd.read_csv('/Users/kevins/Documents/CSImpact/data/cleaned_prof_data_v4.csv')

# %%
college_data = pd.DataFrame()
def plot(college):
    college_no_spaces = college.replace(' ','_').replace('/', '_')
    i = colleges.index[colleges['college'] == f'{college}'].tolist()[0]
    college_data = pd.read_csv(str(os.getcwd()).replace('code/old_test_code', '') + '/data/college_data/college'+str(i)+'.csv')
    missing_id_rows = college_data.loc[college_data['scholar_id'] == 'NOSCHOLARPAGE']
    rows_to_plot = college_data.loc[college_data['scholar_id'] != 'NOSCHOLARPAGE']
    rows = rows_to_plot.shape[0]
    
    missing_profs = missing_id_rows['name']
    text = ''
    for p in missing_profs:
        text += f'{p}, '
    rows_to_plot = college_data.loc[college_data['scholar_id'] != 'NOSCHOLARPAGE']
    rows = rows_to_plot.shape[0]
    
    
    if(rows>5):
        fig_width = rows * 20 + 100
    else:
        fig_width= 400
        
    
    rows_to_plot = rows_to_plot.sort_values('h-index')
    
    desc = rows_to_plot.describe()
    
    
    #h-index
    
    h_indx_mean = float(desc.iloc[1,1])
    print(h_indx_mean)
    
    
    
    h_indexes = rows_to_plot[['h-index']]
    names = rows_to_plot['name']
    
    
    fig = px.scatter(x = names, y = h_indexes, labels = {'x':'name', 'y':'h-index'},title = f'college', width = fig_width, height = 1000, range_y = [0,300], range_x = [-1,rows],)
    fig.add_hline(y=h_indx_mean)
    
    fig.update_layout(title = go.layout.Title(text = f'{college} <br><sup>Average h-index for {rows} professors: {int(h_indx_mean)}</sup>', xref = 'paper', x = 0), font=dict(
               family="Courier New, monospace",
               size=10,
               color="#0000FF"
           ), xaxis=go.layout.XAxis(
        title=go.layout.xaxis.Title(
            text=f'name<br><sup>Professors with missing data: {text}</sup>'
            )
        ))
    fig.write_html(f'/Users/kevins/Documents/CSImpact/data/college_graphs/{college_no_spaces}/{college_no_spaces}_h_index.html')

    
    #citations
    
    cit_mean = float(desc.iloc[1,0])
    print(cit_mean)
    
    rows_to_plot = rows_to_plot.sort_values('citations')
    names = rows_to_plot['name']
    
    citations = rows_to_plot[['citations']]

    fig = px.scatter(x = names, y = citations, labels = {'x':'name', 'y':'citations'}, title = f'{college}', width = fig_width, height = 1000, range_y = [-100,500000], range_x = [-1,rows])
    fig.add_hline(y=cit_mean)
    
    fig.update_layout(title=go.layout.Title(text=f'Average citations for {rows} professors: {int(cit_mean)}', font=dict(
               family="Courier New, monospace",
               size=14,
               color="#0000FF"
      )))
    
    fig.write_html(f'/Users/kevins/Documents/CSImpact/data/college_graphs/{college_no_spaces}/{college_no_spaces}_citations.html')

# %%
for i in range(colleges.shape[0]):
    plot(f'{colleges.iloc[i,0]}')
# Out:
# 30.227272727272727
# 5743.681818181818
# 25.375
# 4011.8
# 30.488372093023255
# 5960.325581395349
# 23.875
# 3479.85
# 24.0
# 3463.0714285714284
# 12.0
# 601.0
# 16.8
# 1792.0
# 20.95
# 2144.15
# 15.375
# 1097.625
# 36.44444444444444
# 9222.111111111111
# 23.846153846153847
# 16910.044444444444
# 27.8
# 10439.066666666668
# 27.055555555555557
# 4907.444444444444
# 14.296296296296296
# 1982.037037037037
# 25.0
# 2654.8571428571427
# 17.466666666666665
# 2390.3333333333335
# 25.242424242424242
# 3999.257575757576
# 56.27272727272727
# 25932.409090909092
# 50.61538461538461
# 12627.846153846154
# 38.83720930232558
# 11202.232558139534
# 34.21052631578947
# 6664.421052631579
# 19.97142857142857
# 2562.0857142857144
# 35.57142857142857
# 6548.214285714285
# 34.69230769230769
# 6564.384615384615
# 20.2
# 2606.1
# 18.05
# 2110.1
# 16.666666666666668
# 1997.9444444444443
# 23.0
# 3672.925
# 22.741935483870968
# 4085.2903225806454
# 21.77777777777778
# 5039.111111111111
# 24.0
# 3851.0
# 24.161290322580644
# 3972.1612903225805
# 23.75
# 3403.15
# 21.666666666666668
# 3946.222222222222
# 6.0
# 137.125
# 21.869565217391305
# 8993.260869565218
# 13.529411764705882
# 2471.6470588235293
# 20.333333333333332
# 1678.0
# 15.777777777777779
# 1744.5555555555557
# 23.32
# 4662.28
# 24.31578947368421
# 3432.0
# 17.6
# 1951.84
# 18.375
# 3193.125
# 26.2
# 5823.7
# 17.2
# 2170.7
# 20.25
# 2411.25
# 35.0
# 6448.75
# 25.142857142857142
# 2897.3571428571427
# 21.0
# 2013.0
# 20.5
# 2438.909090909091
# 24.666666666666668
# 2720.3333333333335
# 29.433333333333334
# 7031.733333333334
# 18.945945945945947
# 3058.5
# 21.5
# 3162.4444444444443
# 16.238095238095237
# 1246.142857142857
# 28.058823529411764
# 5514.529411764706
# 38.05
# 9902.15
# 18.0
# 1049.0
# 31.32183908045977
# 7977.954022988506
# 26.962962962962962
# 4654.518518518518
# 17.136363636363637
# 1607.7272727272727
# 10.9
# 987.0
# 33.241379310344826
# 8608.689655172413
# 14.705882352941176
# 1433.2941176470588
# 25.5
# 3799.8333333333335
# 47.964285714285715
# 19594.60714285714
# 30.065934065934066
# 9899.934065934065
# 48.31578947368421
# 15493.894736842105
# 12.142857142857142
# 811.2857142857143
# 27.424242424242426
# 4567.712121212121
# 35.1875
# 6831.541666666667
# 28.166666666666668
# 3921.25
# 39.67857142857143
# 10637.57142857143
# 25.705882352941178
# 3086.470588235294
# 20.666666666666668
# 2450.0833333333335
# 12.85
# 797.5
# 23.73913043478261
# 3200.8478260869565
# 24.266666666666666
# 2947.866666666667
# 27.125
# 3963.75
# 30.37037037037037
# 5601.555555555556
# 22.833333333333332
# 4506.166666666667
# 16.32
# 1429.88
# nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
#       1 for i in range(colleges.shape[0]):
# ----> 2     plot(f'{colleges.iloc[i,0]}')
#
# Input In [90], in plot(college)
#      36 h_indexes = rows_to_plot['h-index']
#      37 names = rows_to_plot['name']
# ---> 40 fig = px.scatter(x = names, y = h_indexes, labels = {'x':'name', 'y':'h-index'},title = f'college', width = fig_width, height = 1000, range_y = [0,300], range_x = [-1,rows],)
#      41 fig.add_hline(y=h_indx_mean)
#      43 fig.update_layout(title = go.layout.Title(text = f'{college} <br><sup>Average h-index for {rows} professors: {int(h_indx_mean)}</sup>', xref = 'paper', x = 0), font=dict(
#      44            family="Courier New, monospace",
#      45            size=10,
#    (...)
#      50         )
#      51     ))
#
# File /usr/local/lib/python3.9/site-packages/plotly/express/_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#
# File /usr/local/lib/python3.9/site-packages/plotly/express/_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File /usr/local/lib/python3.9/site-packages/plotly/express/_core.py:1324, in build_dataframe(args, constructor)
#    1322 if constructor in cartesians:
#    1323     if wide_x and wide_y:
# -> 1324         raise ValueError(
#    1325             "Cannot accept list of column references or list of columns for both `x` and `y`."
#    1326         )
#    1327     if df_provided and no_x and no_y:
#    1328         wide_mode = True
#
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.

# %%
college_data = pd.read_csv(f'/Users/kevins/Documents/CSImpact/data/college_data/college0.csv')

# %%
college_data
# Out:
#                           name  \
# 0                  P. Vassalos
# 1              Stavros Toumpis
# 2          Ion Androutsopoulos
# 3          Michalis K. Titsias
# 4            Vasilios A. Siris
# 5          E. J. Yannakoudakis
# 6           Eugénie Foustoucos
# 7             Vasilis Vassalos
# 8        Diomidis D. Spinellis
# 9              Antonis Dimakis
# 10          Evangelos Markakis
# 11       Panos Constantopoulos
# 12        Georgios Papaioannou
# 13              Nicos Malevris
# 14              Yannis Kotidis
# 15               Ioannis Milis
# 16    Emmanouel A. Giakoumakis
# 17  Theodore K. Apostolopoulos
# 18       Michalis Vazirgiannis
# 19           T. Z. Kalamboukis
# 20       Iordanis Koutsopoulos
# 21             Vana Kalogeraki
# 22           George C. Polyzos
# 23           Giannis F. Marias
# 24        Ioannis Kontoyiannis
# 25         George D. Stamoulis
# 26            George Xylomenos
# 27                P. Katerinis
# 28          Dimitris Gritzalis
#
#                                              homepage     scholar_id  \
# 0   http://pubs.dbs.uni-leipzig.de/aa/aff/Greece/A...  NOSCHOLARPAGE
# 1   https://195.251.255.130/en/faculty/toumpis-sta...   LyiVPKEAAAAJ
# 2                        http://www.aueb.gr/users/ion   4UJm5EQAAAAJ
# 3                   http://www.aueb.gr/users/mtitsias   B-SbkAwAAAAJ
# 4                     http://www.aueb.gr/users/vsiris   Vj3O0cEAAAAJ
# 5      http://www.aueb.gr/Users/yannakoudakis/english   37tD5JsAAAAJ
# 6   https://uregister-ldap.aueb.gr/en/content/appl...   t1TycUYAAAAJ
# 7   https://www.aueb.gr/en/faculty_page/vassalos-v...   oaM-d7QAAAAJ
# 8                        https://www.dmst.aueb.gr/dds   RjXNgA8AAAAJ
# 9                     http://nes.aueb.gr/dimakis.html   DlAhQuIAAAAJ
# 10                  http://pages.cs.aueb.gr/~markakis  NOSCHOLARPAGE
# 11  https://uregister-ldap.aueb.gr/en/faculty/cons...   EAagfCoAAAAJ
# 12                     http://www.aueb.gr/users/gepap   8YSbfqcAAAAJ
# 13  http://www.cs.aueb.gr/en/content/malevris-niko...  NOSCHOLARPAGE
# 14                  http://www.db-net.aueb.gr/kotidis   ykqoK38AAAAJ
# 15  https://uregister-ldap.aueb.gr/en/faculty/mili...   CS8EIi0AAAAJ
# 16  https://www-1.aueb.gr/en/content/new-rector-at...  NOSCHOLARPAGE
# 17        http://ieeexplore.ieee.org/document/4114886   WTg8mXoAAAAJ
# 18                 http://www.db-net.aueb.gr/michalis   aWGJYcMAAAAJ
# 19  https://uregister-ldap.aueb.gr/en/faculty/kala...  NOSCHOLARPAGE
# 20                      http://www.cs.aueb.gr/~jordan   Bq_GqyIAAAAJ
# 21                       http://www2.cs.aueb.gr/~vana   2lpWTDYAAAAJ
# 22                          http://niovi.aueb.gr/~gcp   y-Mxxa0AAAAJ
# 23  http://www.scirp.org/journal/DetailedInforOfEd...   EO_hUg4AAAAJ
# 24                  http://pages.cs.aueb.gr/~yiannisk   K7lsKjcAAAAJ
# 25                   http://nes.aueb.gr/users/gs.html   5uRFCLsAAAAJ
# 26                   http://pages.cs.aueb.gr/~xgeorge   f7tP8gcAAAAJ
# 27   http://www.aueb.gr/pages_en/graduate/masters.php  NOSCHOLARPAGE
# 28  https://www-1.aueb.gr/en/faculty/gritzalis-dim...   5hIalXgAAAAJ
#
#     citations  h-index
# 0         NaN      NaN
# 1      2804.0     21.0
# 2     11918.0     42.0
# 3      5255.0     30.0
# 4      5967.0     31.0
# 5       738.0     14.0
# 6         NaN      NaN
# 7      3723.0     25.0
# 8     11833.0     53.0
# 9       491.0      8.0
# 10        NaN      NaN
# 11     2134.0     28.0
# 12     3092.0     30.0
# 13        NaN      NaN
# 14     6208.0     34.0
# 15      816.0     13.0
# 16        NaN      NaN
# 17     1091.0     16.0
# 18    18477.0     54.0
# 19        NaN      NaN
# 20     5338.0     32.0
# 21     7739.0     38.0
# 22    11622.0     46.0
# 23     1218.0     21.0
# 24     3095.0     29.0
# 25     1685.0     19.0
# 26     4807.0     24.0
# 27        NaN      NaN
# 28    16310.0     57.0

# %%
colleges.head(50)
# Out:
#                                  college
# 0                                   AUEB
# 1                     Aalborg University
# 2                       Aalto University
# 3                      Aarhus University
# 4                 Aberystwyth University
# 5      Air Force Institute of Technology
# 6           American University in Cairo
# 7          American University of Beirut
# 8                       Ariel University
# 9               Arizona State University
# 10                     Auburn University
# 11                    Augusta University
# 12        Australian National University
# 13                           BITS Pilani
# 14                       BITS Pilani-Goa
# 15                                  BUET
# 16                                  BUPT
# 17               Babeș-Bolyai University
# 18                   Bar-Ilan University
# 19             Bauhaus University Weimar
# 20                    Beihang University
# 21    Ben-Gurion University of the Negev
# 22                  Bielefeld University
# 23                    Bilkent University
# 24                 Binghamton University
# 25         Birkbeck University of London
# 26                    Bocconi University
# 27                Boise State University
# 28                        Boston College
# 29                     Boston University
# 30                   Boğaziçi University
# 31                   Brandeis University
# 32  Brandenburg University of Technology
# 33              Brigham Young University
# 34         Brno University of Technology
# 35                      Brown University
# 36              Brunel University London
# 37          Bundeswehr University Munich
# 38                CISPA Helmholtz Center
# 39                                   CMI
# 40                               CRIStAL
# 41                                  CUNY
# 42                                   CWI
# 43    California Institute of Technology
# 44                    Cardiff University
# 45                   Carleton University
# 46            Carnegie Mellon University
# 47       Case Western Reserve University
# 48                           Chalmers/GU
# 49                    Charles University

# %%
#test
#plot('AUEB')

# %%
'Chalmers/GU'.replace(' ','_').replace('/', '_')
# Out:
# 'Chalmers_GU'

# %%
for i in range(colleges.shape[0]):
    college_no_spaces = pd.read_csv(f'/Users/kevins/Documents/CSImpact/data/colleges.csv').iloc[i,0].replace(' ','_').replace('/', '_')
    os.mkdir(f'/Users/kevins/Documents/CSImpact/data/college_graphs/{college_no_spaces}')

# %%
colleges.loc[colleges['college']=='Lancaster University']
# Out:
#                   college
# 176  Lancaster University
