# %%
from cmath import isnan
import os
from random import random
import time
from typing import Any
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from csv import writer

# read the data from a file
data = pd.read_csv(os.getcwd().replace('code/old_test_code','') + "/data/cleaned_prof_data_v4.csv")

# initialize web driver for selenium
options = webdriver.ChromeOptions()
options.add_argument('--disable-blink-features=AutomationControlled')
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
driver.implicitly_wait(random() * 10)


def findMaxCitations(web_elements: list):
    indOfMax = 0
    maxVal = 0
    for i in range(len(web_elements)):
        val = int(web_elements[i].text.split(" - ")[2].split(" ")[2])
        if val > maxVal:
            maxVal = val
            indOfMax = i
        else:
            continue
    return web_elements[indOfMax]


# loop through and find all professors with wrong / no google scholar ID
professors = []
professorExists = True

for i in range(13595, data.shape[0]):

    # initialize values
    scholar_id = data.iat[i, 3],
    citations = data.iat[i, 4],
    h_index = data.iat[i, 5]

    if(data.iat[i, 3] == "NOSCHOLARPAGE" or data.iat[i, 3] == "#NAME?" or isnan(data.iat[i, 4]) or isnan(data.iat[i, 5])):
        print("Name: " + data.iat[i, 0] + " | " + "University: " +
              data.iat[i, 1] + " | " + "id: " + data.iat[i, 3])

        # launch URL
        driver.get("https://scholar.google.com")

        # identify search box
        box = driver.find_element(By.NAME, "q")

        # enter search text
        box.send_keys(data.iat[i, 0] + " " + data.iat[i, 1])

        # make search
        box.send_keys(Keys.ENTER)

        # in the case that the author pops up as a recommended option
        try:
            link = driver.find_element(
                By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]/h4/a")
            link.click()
            time.sleep(random() * 3)
            
        except:
            try:
                # in the case there are multiple options in the recommended table
                list_of_elements = driver.find_element(
                    By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]").find_elements(By.TAG_NAME, "div")
                print("case 2 was executed")
                max_element = findMaxCitations(list_of_elements)
                max_element.find_element(By.TAG_NAME, "a").click()
                time.sleep(random() * 5)
            except:
                # otherwise loop through all the divs and find the correct professor
                elements_list = driver.find_element(
                    By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]").find_element(By.CLASS_NAME, "gs_a").find_elements(By.TAG_NAME, "a")
                print(elements_list)
                if elements_list: 
                    for element in elements_list:  # looping through the number of professors in the link
                        try:
                            element.find_element(By.TAG_NAME, "b")
                            element.click()
                            professorExists = True
                            break
                        except NoSuchElementException:
                            professorExists = False
                            continue  # in the case that the element is not found
                    # give time for html / css / js to load
                    time.sleep(random() * 5)
                else: 
                    professorExists = False 

        # retrieve citation, h-index, and scholar_id for that prof
        if professorExists:
            scholar_id = driver.current_url.split("=")[1].split("&")[0]
            citation = driver.find_element(
                By.XPATH, "//*[@id='gsc_rsb_st']/tbody/tr[1]/td[2]").text
            h_index = driver.find_element(
                By.XPATH, "//*[@id='gsc_rsb_st']/tbody/tr[2]/td[2]").text
            time.sleep(random() * 5)
        else:
            scholar_id = None
            citation = None
            h_index = None
        print("scholar_id: " + str(scholar_id) + " h-index: " +
              str(h_index) + " citations: " + str(citation))
        professors.append({
            "Name": data.iat[i, 0],
            "affiliation": data.iat[i, 1],
            "homepage": data.iat[i, 2],
            "scholar-id": scholar_id,
            "citations": citation,
            "h-index": h_index
        })
    else:
        continue


print(len(professors))
df = pd.DataFrame(professors)
df.to_csv("cleaned_prof_data_v5_33.csv")
# Out:
# [WDM] - ====== WebDriver manager ======
# 2022-07-19 13:08:42,301 INFO ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# 2022-07-19 13:08:42,388 INFO Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# 2022-07-19 13:08:42,391 INFO Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/kevins/.wdm/drivers/chromedriver/mac64/103.0.5060.53/chromedriver] found in cache
# 2022-07-19 13:08:42,524 INFO Driver [/Users/kevins/.wdm/drivers/chromedriver/mac64/103.0.5060.53/chromedriver] found in cache
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_59127/3416575854.py:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# Name: Michael Hatzopoulos | University: University of Athens | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="00f8d338-4561-4904-9cea-26dcd2e22899")>]
# scholar_id: None h-index: None citations: None
# Name: Aggeliki Arapoyanni | University: University of Athens | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Alex Delis | University: University of Athens | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Clark D. Thomborson | University: University of Auckland | id: jFEDehcAAAAJ
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="6ff82a12-eb30-4629-bf31-cfc466cec4d0")>]
# scholar_id: bSpUhd0AAAAJ h-index: 39 citations: 12400
# Name: André Nies | University: University of Auckland | id: NOSCHOLARPAGE
# scholar_id: zVPfH-QAAAAJ h-index: 32 citations: 4670
# Name: David Welch | University: University of Auckland | id: W3-SgVAAAAAJ
# scholar_id: V7sqis8AAAAJ h-index: 17 citations: 2905
# Name: Ulrich Günther | University: University of Auckland | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Radu Nicolescu | University: University of Auckland | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Xinfeng Ye | University: University of Auckland | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="ed54c8cd-545b-435d-a2ac-bce9909acc5d")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="aabd2401-4886-43f6-98a1-81d08785748e")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="4eddfc56-7b6d-484f-9694-62f8f35bdcf7")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="09a8237e-8ab9-4763-a380-1c91cc75a4e9")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="905a7eaf-1bc4-4298-b200-02b270874c21")>]
# scholar_id: 1BooF3oAAAAJ h-index: 12 citations: 488
# Name: Sathiamoorthy Manoharan | University: University of Auckland | id: NOSCHOLARPAGE
# scholar_id: 2h0XFe8AAAAJ h-index: 13 citations: 1010
# Name: Damir Azhar | University: University of Auckland | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="2ab356a4-7996-4d3c-a9ef-9e134fa82797")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="c5fea13c-33fd-45b5-8bb0-5e6660a1f4e4")>]
# scholar_id: None h-index: None citations: None
# Name: Johannes Schilp | University: University of Augsburg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="5194c7dd-f60d-447f-baf7-5f3a342bc983")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="719f3b50-4c48-4ee9-b367-6447a89d9b73")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d863cd92-deec-45c8-ae05-6e6c6adf28e7")>]
# scholar_id: None h-index: None citations: None
# Name: Theo Ungerer | University: University of Augsburg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="f3356178-0fdd-470d-a6af-4d1857be0e42")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="41e2bd44-6b44-4f7c-a423-92c140b6b225")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="a9b8e8e7-bd45-4e3e-980d-23121206fab3")>]
# scholar_id: None h-index: None citations: None
# Name: Wolfgang Reif | University: University of Augsburg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="fd87c4a8-7154-47e3-b573-33d716d7e473")>]
# scholar_id: None h-index: None citations: None
# Name: Lars Mikelsons | University: University of Augsburg | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Walter Vogler | University: University of Augsburg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="3ad1015d-2a22-426f-823a-d398e90efd51")>]
# scholar_id: None h-index: None citations: None
# Name: Torben Hagerup | University: University of Augsburg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="ca6b047d-6ac6-463e-8236-88bb6382e4e9")>]
# scholar_id: None h-index: None citations: None
# Name: Christoph Ament | University: University of Augsburg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="ffde25bc-a81d-42f2-bc3d-8d902f2e5f2c")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="fc58e5c7-b0d0-4c36-aade-5d0a07916e60")>]
# scholar_id: 4aVqJJMAAAAJ h-index: 15 citations: 1143
# Name: Rudi Knorr | University: University of Augsburg | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Jukka Matthias Krisp | University: University of Augsburg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="36bb9761-bb9b-4de6-86f8-d3f21190905f")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="a49621ea-8912-43c9-b8b9-1c6e53623607")>]
# scholar_id: KnEUPRcAAAAJ h-index: 16 citations: 1165
# Name: Gerald Lüttgen | University: University of Bamberg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="b884adaf-f133-49c2-bd20-03689098c300")>]
# scholar_id: None h-index: None citations: None
# Name: Udo R. Krieger | University: University of Bamberg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d1b4acf2-72bf-4022-83ae-15cc5c8c87e2")>]
# scholar_id: None h-index: None citations: None
# Name: Christoph Schlieder | University: University of Bamberg | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="b50342cc-29f5-4239-ad86-b9748971c86a")>]
# scholar_id: None h-index: None citations: None
# Name: Michael Mendler | University: University of Bamberg | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Peter Hall | University: University of Bath | id: Tgz4GT8AAAAJ
# scholar_id: None h-index: None citations: None
# Name: Rachid Hourizi | University: University of Bath | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="a853f30d-e285-43b4-ae42-ec5ebb725ca8")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="3f652856-11ec-4969-adef-a90a49ea1edb")>]
# scholar_id: None h-index: None citations: None
# Name: Fabio Nemetz | University: University of Bath | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="268f33f5-29fd-492e-a001-f3bd8ba0ddda")>]
# scholar_id: None h-index: None citations: None
# Name: Alan Hayes | University: University of Bath | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="28843c4d-6aaa-4e4d-9b59-2804533bfc06")>]
# scholar_id: None h-index: None citations: None
# Name: Leon A. Watts | University: University of Bath | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="76dbb46e-53b9-459c-a8d6-5061a7852cdf")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="662ae4e5-243a-4889-a752-2ef0ffa2ae4b")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="c00de8b3-7571-4230-b29c-4f9897201a4c")>]
# scholar_id: zhwMZx4AAAAJ h-index: 22 citations: 1777
# Name: Dominik Henrich | University: University of Bayreuth | id: w8FwIsEAAAAJ
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="bfb834d4-6b79-4104-9d6e-eb03e3b44520")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="bd9de332-7a17-4c8a-8d97-c43fe9d72a30")>]
# scholar_id: j0M2CKsAAAAJ h-index: 26 citations: 2651
# Name: Matthias Korch | University: University of Bayreuth | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Stefan Jablonski | University: University of Bayreuth | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d4568481-60c9-4763-b90a-802530b59ee3")>]
# scholar_id: None h-index: None citations: None
# Name: Thomas Rauber | University: University of Bayreuth | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Duc-Tien Dang-Nguyen | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Dag Haugland | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Igor A. Semaev | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="edf653f5-260b-43d0-9cfa-c9f8e11fbd03")>]
# scholar_id: None h-index: None citations: None
# Name: Matthew G. Parker | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="7c5af6b5-5da1-436d-ab62-748c47d18054")>]
# scholar_id: U3Er8bsAAAAJ h-index: 22 citations: 1921
# Name: Michael R. Fellows | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="3114e169-3a16-49bf-b0ff-bb24ab35614d")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="b1cb52c7-4d8b-417e-8033-64dd91f4d64c")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="82c6984c-4446-4e7a-aaff-9832a6e434da")>]
# scholar_id: rLCC8mQAAAAJ h-index: 64 citations: 19061
# Name: Petter Bjørstad | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: y5aoMlYAAAAJ h-index: 22 citations: 2249
# Name: Lilya Budaghyan | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: E4UDXnMAAAAJ h-index: 20 citations: 1605
# Name: Frances Rosamond | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: k5StrAoAAAAJ h-index: 33 citations: 3612
# Name: Ketil Malde | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: NhtWxjsAAAAJ h-index: 18 citations: 1872
# Name: Inge Jonassen | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: RqvFRN4AAAAJ h-index: 50 citations: 12656
# Name: Fredrik Manne | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: K-N0vTcAAAAJ h-index: 31 citations: 2640
# Name: Stefan Bruckner | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: 23uJZDoAAAAJ h-index: 31 citations: 3686
# Name: Michael Dondrup | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: 2kVcaAYAAAAJ h-index: 18 citations: 1682
# Name: Sjur Didrik Flåm | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="a8b469ec-9ec7-4701-b45b-19b450e23c84")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d7de2bb4-2eb4-4f4b-b233-1ab449a13872")>]
# scholar_id: GwHg0VAAAAAJ h-index: 17 citations: 1798
# Name: Helwig Hauser | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: x4jXO7AAAAAJ h-index: 62 citations: 12813
# Name: Marc Bezem | University: University of Bergen | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Pekka Parviainen | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Marco Calderini | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="e38623f0-e0bf-45cb-8bf0-176477c1d0af")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="dc69621e-ae4a-40ef-8112-8a2f8c093c03")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="6dad6fff-ff9d-4ebc-b9b3-ec5db59e4e04")>]
# scholar_id: y2A12kkAAAAJ h-index: 11 citations: 324
# Name: Håkon Robbestad Gylterud | University: University of Bergen | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: David Grellscheid | University: University of Bergen | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Petr A. Golovach | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="5203bfa5-b877-45fb-a262-b319b9ceaf77")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="1dd8a7a7-1840-4996-8d25-ba51d0a94b27")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="b40d278c-5950-43a0-8fa3-ef6e59dfebca")>]
# scholar_id: aN2vJYUAAAAJ h-index: 31 citations: 3586
# Name: Jan-J. Rückmann | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="555b0004-5662-4c0b-a871-9d67cde31feb")>]
# scholar_id: U2MWZn4AAAAJ h-index: 20 citations: 1626
# Name: Anya Helene Bagge | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: lwEnPTUAAAAJ h-index: 9 citations: 345
# Name: Torleiv Kløve | University: University of Bergen | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Tor Helleseth | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Jan Arne Telle | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Sverre Storøy | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="3caac40e-0b27-4677-964d-64a19282fd21")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d91bf99d-8231-4c33-a945-19a8085498a0")>]
# scholar_id: None h-index: None citations: None
# Name: Pinar Heggernes | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Ahmad Hemmati | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Andreas L. Opdahl | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: ChunLei Li | University: University of Bergen | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Magne Haveraaen | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="456aac6b-d320-415d-ba70-3e5fd9ebf3e1")>]
# scholar_id: None h-index: None citations: None
# Name: Jaakko Järvi | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="5db232a3-2a87-487b-9070-cf36f2f197a8")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="9f84b47e-d4cc-458d-8e8b-71800f2eca86")>]
# scholar_id: J0rDv4oAAAAJ h-index: 18 citations: 1555
# Name: Trond Steihaug | University: University of Bergen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="146b4668-73fb-4a0f-a20a-dc899ff473ac")>]
# scholar_id: tMJ5VJAAAAAJ h-index: 21 citations: 5010
# Name: Nicolai Kraus | University: University of Birmingham | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="37b3fe83-6d2c-4da0-964b-0b7143211f97")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="f2989d2c-2983-448f-9540-3901e2df9da2")>]
# scholar_id: g2bTiKAAAAAJ h-index: 13 citations: 635
# Name: Michael Meier | University: University of Bonn | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="9b68bd94-414b-434a-a888-f7f96d0eaf78")>]
# scholar_id: None h-index: None citations: None
# Name: Norbert Blum | University: University of Bonn | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Joachim K. Anlauf | University: University of Bonn | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Matthew Smith | University: University of Bonn | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="9e2bc08e-2289-4c31-b558-02b398d76c2f")>]
# scholar_id: None h-index: None citations: None
# Name: Wolfgang Koch | University: University of Bonn | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="9ff8947e-ea21-4452-99f9-c363eb8fd4e2")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="bf50f5b2-e2bf-4052-b0b6-bd2c5c02e4f2")>]
# scholar_id: None h-index: None citations: None
# Name: Reinhard Klein | University: University of Bonn | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Stefan Wrobel | University: University of Bonn | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Angela Yao | University: University of Bonn | id: #NAME?
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="37d98608-5cbc-4bfd-9b5d-03d9bee5be39")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="595f30f7-495d-460f-acfc-490a833090d3")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="a34eec9f-3cc5-4f29-a92c-e8393f870feb")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d224bd89-540c-46a3-bc00-3af55613c954")>]
# scholar_id: -LJCZMMAAAAJ h-index: 26 citations: 3408
# Name: Peter Martini | University: University of Bonn | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="6ea7e466-503f-44e9-bf3d-074677a4288b")>]
# scholar_id: None h-index: None citations: None
# Name: Kerstin Schill | University: University of Bremen | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Ute Bormann | University: University of Bremen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="941cb24f-40c5-468e-9408-2145ec4f5898")>]
# scholar_id: None h-index: None citations: None
# Name: Andreas Breiter | University: University of Bremen | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="cb27bef8-c8c7-4edc-a450-b48fe526c946")>]
# scholar_id: None h-index: None citations: None
# Name: Jan Peleska | University: University of Bremen | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Theo Tryfonas | University: University of Bristol | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Kerstin Eder | University: University of Bristol | id: SyDaZIoAAAAJ
# scholar_id: None h-index: None citations: None
# Name: Steven J. Ramsay | University: University of Bristol | id: mxxKCzcAAAAJ
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="4bde7b36-34b9-4297-8078-cf5b8dc389c3")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="6672d580-961b-4c29-9d1b-ea1d1ee813b5")>]
# scholar_id: 68os7K8AAAAJ h-index: 9 citations: 382
# Name: Kirsten Cater | University: University of Bristol | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d86e20e8-759d-4701-b1ee-81dd1a706b43")>]
# scholar_id: None h-index: None citations: None
# Name: Ian Holyer | University: University of Bristol | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="c2175f1e-94ea-4db0-93ca-a9d62232ffb5")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="ad6e1a69-b880-45e3-b653-d8608a06a7e7")>]
# scholar_id: None h-index: None citations: None
# Name: Anne Roudaut | University: University of Bristol | id: 03epP5wAAAAJ
# scholar_id: None h-index: None citations: None
# Name: Tilo Burghardt | University: University of Bristol | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Sathish Gopalakrishnan | University: University of British Columbia | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Joel Friedman | University: University of British Columbia | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Mark R. Greenstreet | University: University of British Columbia | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="cae16c5b-cbaa-4eac-ba6f-910d48aac97c")>]
# scholar_id: None h-index: None citations: None
# Name: Leonid Sigal | University: University of British Columbia | id: Ywx45aQAAAAJ
# scholar_id: None h-index: None citations: None
# Name: Michael P. Friedlander | University: University of British Columbia | id: mOgIIH4AAAAJ
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="2c67ed05-fbb2-45ca-a1a7-8a74a993b082")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="a02fc047-bd59-408d-8ebb-8d81909481ce")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="22f9f4af-fa78-457e-b4f4-9cc5a64c1ad5")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="12c8e707-61f6-4fe0-984d-deec0a130920")>]
# scholar_id: mOgIIH4AAAAJ h-index: 28 citations: 9954
# Name: Chen Greif | University: University of British Columbia | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="97fa99cf-dddc-4c56-a5c4-a53ce017e7d2")>]
# scholar_id: None h-index: None citations: None
# Name: Siamak (Moshen) Ravanbakhsh | University: University of British Columbia | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Norman C. Hutchinson | University: University of British Columbia | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="6ceb655f-2d09-4f73-9a37-749db4e42192")>]
# scholar_id: dbN2vS4AAAAJ h-index: 33 citations: 8612
# Name: Marcelo Risk | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="cc5c1ebd-bc71-48a2-9a37-ca9281291eb8")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="417e91fb-c46e-4839-b835-2bd67e079eb9")>]
# scholar_id: Y6QTnx4AAAAJ h-index: 20 citations: 1342
# Name: Isabel Méndez-Díaz | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="81a9d69c-a529-45bd-88ce-483cc9faeac4")>]
# scholar_id: None h-index: None citations: None
# Name: Víctor A. Braberman | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="63c4c3b3-96c3-41c4-b7e7-2e3e5e5bba8e")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="4996df86-01bc-4269-9a5b-5d5ad188cead")>]
# scholar_id: None h-index: None citations: None
# Name: Hernán Wilkinson | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="4e0cc7b4-822a-4282-81fe-d06c4a02c0d4")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="68014637-99df-4fa0-945b-44b94e365d25")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="6b3cc570-82d9-411f-a512-00bc0f1f6c51")>]
# scholar_id: None h-index: None citations: None
# Name: Pablo G. Turjanski | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="beb10712-4fae-41fc-b3e6-aad427884a19")>]
# scholar_id: None h-index: None citations: None
# Name: Francisco J. Soulignac | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="9078ff3e-a134-4beb-ab15-81376058e933")>, <selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="d3bf2bd2-5057-4f3c-9036-070e1ccfd41e")>]
# scholar_id: None h-index: None citations: None
# Name: Enrique Carlos Segura | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="5413d185-1e02-466b-b656-3ce06810d259")>]
# scholar_id: None h-index: None citations: None
# Name: Javier L. Marenco | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="58d2a352-2126-4c78-9626-4144fd587b20")>]
# scholar_id: None h-index: None citations: None
# Name: Santiago Ceria | University: University of Buenos Aires | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Claudio E. Righetti | University: University of Buenos Aires | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="bcee239fc6f03d26e5e8d96f5c60c050", element="7c09435d-61b6-486c-a818-f9a6cada2ca4")>]

# %%
df
# Out:
#                        Name                           affiliation  \
# 0              Peter Slater    University of Alabama - Huntsville
# 1             Huaming Zhang    University of Alabama - Huntsville
# 2            Mikel D. Petty    University of Alabama - Huntsville
# 3             Haeyong Chung    University of Alabama - Huntsville
# 4      Heggere S. Ranganath    University of Alabama - Huntsville
# 5          Daniel Rochowiak    University of Alabama - Huntsville
# 6            Sara J. Graves    University of Alabama - Huntsville
# 7               Feng W. Zhu    University of Alabama - Huntsville
# 8               Li-Yan Yuan                 University of Alberta
# 9          Janelle J. Harms                 University of Alberta
# 10               Hong Zhang                 University of Alberta
# 11         David S. Wishart                 University of Alberta
# 12             Jia-Huai You                 University of Alberta
# 13         Ehab S. Elmallah                 University of Alberta
# 14         Denilson Barbosa                 University of Alberta
# 15               Renee Elio                 University of Alberta
# 16        Richard S. Sutton                 University of Alberta
# 17         Lorna K. Stewart                 University of Alberta
# 18        Ioanis Nikolaidis                 University of Alberta
# 19           José N. Amaral                 University of Alberta
# 20          James R. Wright                 University of Alberta
# 21             Michael Buro                 University of Alberta
# 22            Zac Friggstad                 University of Alberta
# 23  Jan-Willem van de Meent               University of Amsterdam
# 24           Khalil Sima'an               University of Amsterdam
# 25            Sandiway Fong                 University of Arizona
# 26          Peter J. Downey                 University of Arizona
# 27               Alon Efrat                 University of Arizona
# 28           Beichuan Zhang                 University of Arizona
# 29                   Jia Di                University of Arkansas
# 30               Yarui Peng                University of Arkansas
# 31           Gordon Beavers                University of Arkansas
# 32            David Andrews                University of Arkansas
# 33          Michael Gashler                University of Arkansas
# 34            John M. Gauch                University of Arkansas
# 35       James P. Parkerson                University of Arkansas
# 36           Miaoqing Huang                University of Arkansas
# 37              Susan Gauch                University of Arkansas
# 38          Brajendra Panda                University of Arkansas
# 39             Wing Ning Li                University of Arkansas
# 40         Dale R. Thompson                University of Arkansas
# 41             Xiaoqing Liu                University of Arkansas
# 42           Steven Minsker  University of Arkansas - Little Rock
# 43            Coskun Bayrak  University of Arkansas - Little Rock
#
#                                              homepage    scholar-id citations  \
# 0   https://www.uah.edu/science/departments/math/f...          None      None
# 1   https://www.uah.edu/science/departments/comput...          None      None
# 2   https://www.uah.edu/images/research/cmsa/pdf/P...          None      None
# 3   https://www.uah.edu/science/departments/comput...          None      None
# 4   https://www.uah.edu/science/departments/comput...          None      None
# 5   https://www.uah.edu/science/departments/comput...          None      None
# 6   https://www.uah.edu/science/departments/comput...          None      None
# 7   https://www.uah.edu/science/departments/comput...          None      None
# 8                https://webdocs.cs.ualberta.ca/~yuan          None      None
# 9               https://webdocs.cs.ualberta.ca/~harms          None      None
# 10              https://webdocs.cs.ualberta.ca/~zhang          None      None
# 11                          http://www.wishartlab.com  -JSn-WgAAAAJ    106556
# 12                https://webdocs.cs.ualberta.ca/~you          None      None
# 13               https://webdocs.cs.ualberta.ca/~ehab  wa0vQsYAAAAJ       556
# 14                  https://www.ualberta.ca/~denilson  zd0qalEAAAAJ      2523
# 15                https://webdocs.cs.ualberta.ca/~ree          None      None
# 16             https://webdocs.cs.ualberta.ca/~sutton          None      None
# 17             http://webdocs.cs.ualberta.ca/~stewart          None      None
# 18              http://webdocs.cs.ualberta.ca/~yannis          None      None
# 19             https://webdocs.cs.ualberta.ca/~amaral  iLDfcPEAAAAJ      2517
# 20                               http://jrwright.info  -BEP3TYAAAAJ       664
# 21                         https://skatgame.net/mburo          None      None
# 22           https://webdocs.cs.ualberta.ca/~zacharyf          None      None
# 23                 https://www.ccs.neu.edu/home/jwvdm          None      None
# 24                 https://staff.fnwi.uva.nl/k.simaan          None      None
# 25               http://elmo.sbs.arizona.edu/sandiway          None      None
# 26                   https://www.cs.arizona.edu/~pete          None      None
# 27              http://www.cs.arizona.edu/people/alon  1PzuGVwAAAAJ      1251
# 28                 https://www.cs.arizona.edu/~bzhang  -IMW-w0AAAAJ     11361
# 29                         https://sites.uark.edu/jdi  Yu-Gl1AAAAAJ      2029
# 30                      https://sites.uark.edu/yrpeng  4e9jdpMAAAAJ       442
# 31                http://csce.uark.edu/~gordonb/index          None      None
# 32                 http://www.csce.uark.edu/~dandrews          None      None
# 33                     http://csce.uark.edu/~mgashler  nlZtV-8AAAAJ       784
# 34                       http://csce.uark.edu/~jgauch  R0EQOKEAAAAJ      2228
# 35                 http://www.csce.uark.edu/~jparkers          None      None
# 36                  http://www.csce.uark.edu/~mqhuang          None      None
# 37                   http://www.csce.uark.edu/~sgauch          None      None
# 38                       http://csce.uark.edu/~bpanda          None      None
# 39  https://engineering.uark.edu/directory/index/u...          None      None
# 40                          https://www.netgeekdr.com  AKyy-y0AAAAJ       524
# 41  https://computer-science-and-computer-engineer...  8ac8nKkAAAAJ      3500
# 42  https://ualr.edu/computerscience/about/faculty...          None      None
# 43              http://ualr.academia.edu/CoskunBayrak  3rf7Z2gAAAAJ      1478
#
#    h-index
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11     124
# 12    None
# 13      14
# 14      28
# 15    None
# 16    None
# 17    None
# 18    None
# 19      24
# 20      12
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27       5
# 28      42
# 29      23
# 30      11
# 31    None
# 32    None
# 33      13
# 34      23
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40      12
# 41      31
# 42    None
# 43      21

# %%
professors
# Out:
# [{'Name': 'Shucheng Yu',
#   'affiliation': 'University of Arkansas - Little Rock',
#   'homepage': 'https://ualr.edu/faculty-7wazt/yu',
#   'scholar-id': 'RtatFnQAAAAJ',
#   'citations': '1085',
#   'h-index': '19'},
#  {'Name': 'Mariofanna Milanova',
#   'affiliation': 'University of Arkansas - Little Rock',
#   'homepage': 'http://ualr.academia.edu/MariofannaMilanova',
#   'scholar-id': '0reJ924AAAAJ',
#   'citations': '1109',
#   'h-index': '16'},
#  {'Name': 'Kenji Yoshigoe',
#   'affiliation': 'University of Arkansas - Little Rock',
#   'homepage': 'https://ualr.edu/eit/2017/02/10/dr-kenji-yoshigoe-2017',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Peiyi Tang',
#   'affiliation': 'University of Arkansas - Little Rock',
#   'homepage': 'http://www.ualr.edu/pxtang',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Stathes Hadjiefthymiades',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://cgi.di.uoa.gr/~shadj',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Georgios Kouroupetroglou',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://speech.di.uoa.gr/koupe/koupe.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Elias S. Manolakos',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://gain.di.uoa.gr/index.php/the-group-members/faculty-members/manolakos',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Sergios Theodoridis',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://cgi.di.uoa.gr/~stheodor',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Vassilis Zissimopoulos',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://cgi.di.uoa.gr/~vassilis',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ioannis Stavrakakis',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://cgi.di.uoa.gr/~istavrak',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Dimitris Syvridis',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://www.photonics.di.uoa.gr/index.php/prof-dimitris-syvridis',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'P. Takis Mathiopoulos',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://gain.di.uoa.gr/index.php/the-group-members/faculty-members/p-takis-mathiopoulos',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Alexandros Eleftheriadis',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://itmb.di.uoa.gr/education/didaskontesEng/edu_didakt7.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Nicholas Kalouptsidis',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://www.di.uoa.gr/eng/staff/1004',
#   'scholar-id': 'dTRfhpYAAAAJ',
#   'citations': '4021',
#   'h-index': '31'},
#  {'Name': 'Thomas Sfikopoulos',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://www.di.uoa.gr/eng/staff/1158',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Filippos Tzaferis',
#   'affiliation': 'University of Athens',
#   'homepage': 'http://www.di.uoa.gr/eng/staff/1028',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None}]

# %%
h_index
# Out:
# 54.0

# %%
data
# Out:
#                       name         affiliation  \
# 0              P. Vassalos                AUEB
# 1          Stavros Toumpis                AUEB
# 2      Ion Androutsopoulos                AUEB
# 3      Michalis K. Titsias                AUEB
# 4        Vasilios A. Siris                AUEB
# ...                    ...                 ...
# 20644         Ali C. Begen  Özyeğin University
# 20645          Erhan Öztop  Özyeğin University
# 20646         Yasar Safkan  Özyeğin University
# 20647          Hasan Sözer  Özyeğin University
# 20648           Emre Sefer  Özyeğin University
#
#                                                 homepage     scholar_id  \
# 0      http://pubs.dbs.uni-leipzig.de/aa/aff/Greece/A...  NOSCHOLARPAGE
# 1      https://195.251.255.130/en/faculty/toumpis-sta...   LyiVPKEAAAAJ
# 2                           http://www.aueb.gr/users/ion   4UJm5EQAAAAJ
# 3                      http://www.aueb.gr/users/mtitsias   B-SbkAwAAAAJ
# 4                        http://www.aueb.gr/users/vsiris   Vj3O0cEAAAAJ
# ...                                                  ...            ...
# 20644                              https://ali.begen.net   ZIZWsXoAAAAJ
# 20645  https://robotics.ozyegin.edu.tr/members/erhan-...   A8YEQMMAAAAJ
# 20646   https://cs.ozyegin.edu.tr/en/faculty/yasarsafkan  NOSCHOLARPAGE
# 20647              https://faculty.ozyegin.edu.tr/hsozer   L3FuUX0AAAAJ
# 20648                           http://www.emresefer.com   W5qWthcAAAAJ
#
#        citations  h-index
# 0            NaN      NaN
# 1         2804.0     21.0
# 2        11918.0     42.0
# 3         5255.0     30.0
# 4         5967.0     31.0
# ...          ...      ...
# 20644     5964.0     34.0
# 20645     3702.0     28.0
# 20646        NaN      NaN
# 20647      847.0     16.0
# 20648      253.0     10.0
#
# [20649 rows x 6 columns]

# %%
data.loc[data['name'] == 'Serafeim Karampogias']
# Out:
#                        name           affiliation  \
# 13594  Serafeim Karampogias  University of Athens
#
#                                   homepage     scholar_id  citations  h-index
# 13594  http://www.di.uoa.gr/eng/staff/1179  NOSCHOLARPAGE        NaN      NaN

# %%
print(len(professors))
df = pd.DataFrame(professors)
df.to_csv("cleaned_prof_data_v5_32.csv")
# Out:
# 16

# %%
professors.append({'Name': 'Serafeim Karampogias',
  'affiliation': 'University of Athens',
  'homepage': 'None',
  'scholar-id': 'None',
  'citations': 'None',
  'h-index': 'None'})
