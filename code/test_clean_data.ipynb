# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/kevins/Documents/CSImpact/data/all_prof_data.csv')

# %%
data.head()
# Out:
#                  name              affiliation  \
# 0          A Min Tjoa                  TU Wien
# 1   A. Akbari Azirani                     IUST
# 2    A. Akbariazirani                     IUST
# 3      A. Aldo Faisal  Imperial College London
# 4  A. Antony Franklin            IIT Hyderabad
#
#                                             homepage     scholarid
# 0                   http://www.ifs.tuwien.ac.at/tjoa  x8qCMhcAAAAJ
# 1  http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...  pCil4_cAAAAJ
# 2  http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...  pCil4_cAAAAJ
# 3         https://www.imperial.ac.uk/people/a.faisal  WjHjbrwAAAAJ
# 4           http://www.iith.ac.in/~antony/index.html  LVfqLuoAAAAJ

# %%
data.shape
# Out:
# (25189, 4)

# %%
data_2 = data.drop_duplicates()

# %%
data_2.shape
# Out:
# (25189, 4)

# %%
data_3 = data.drop(['name'], axis = 1)

# %%
data_3
# Out:
#                            affiliation  \
# 0                              TU Wien
# 1                                 IUST
# 2                                 IUST
# 3              Imperial College London
# 4                        IIT Hyderabad
# ...                                ...
# 25184  Georgia Institute of Technology
# 25185              New York University
# 25186    Weizmann Institute of Science
# 25187               University of Utah
# 25188    University of Texas at Dallas
#
#                                                 homepage      scholarid
# 0                       http://www.ifs.tuwien.ac.at/tjoa   x8qCMhcAAAAJ
# 1      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...   pCil4_cAAAAJ
# 2      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...   pCil4_cAAAAJ
# 3             https://www.imperial.ac.uk/people/a.faisal   WjHjbrwAAAAJ
# 4               http://www.iith.ac.in/~antony/index.html   LVfqLuoAAAAJ
# ...

# %%
data_3_no_dupes = data_3.drop_duplicates()

# %%
data_3_no_dupes
# Out:
#                            affiliation  \
# 0                              TU Wien
# 1                                 IUST
# 3              Imperial College London
# 4                        IIT Hyderabad
# 5                                 BUET
# ...                                ...
# 25184  Georgia Institute of Technology
# 25185              New York University
# 25186    Weizmann Institute of Science
# 25187               University of Utah
# 25188    University of Texas at Dallas
#
#                                                 homepage      scholarid
# 0                       http://www.ifs.tuwien.ac.at/tjoa   x8qCMhcAAAAJ
# 1      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...   pCil4_cAAAAJ
# 3             https://www.imperial.ac.uk/people/a.faisal   WjHjbrwAAAAJ
# 4               http://www.iith.ac.in/~antony/index.html   LVfqLuoAAAAJ
# 5           https://sites.google.com/site/abmalimalislam   K-AIPzQAAAAJ
# ...

# %%
data4_no_dupes=data_3_no_dupes.merge(data, how='left', on=['affiliation','homepage','scholarid'])

# %%
data4_no_dupes
# Out:
#                            affiliation  \
# 0                              TU Wien
# 1                              TU Wien
# 2                                 IUST
# 3                                 IUST
# 4                                 IUST
# ...                                ...
# 25184  Georgia Institute of Technology
# 25185              New York University
# 25186    Weizmann Institute of Science
# 25187               University of Utah
# 25188    University of Texas at Dallas
#
#                                                 homepage      scholarid  \
# 0                       http://www.ifs.tuwien.ac.at/tjoa   x8qCMhcAAAAJ
# 1                       http://www.ifs.tuwien.ac.at/tjoa   x8qCMhcAAAAJ
# 2      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...   pCil4_cAAAAJ
# 3      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...   pCil4_cAAAAJ
# 4      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...   pCil4_cAAAAJ
# ...

# %%
 data_4_no_dupes= data.groupby(['affiliation', 'homepage', 'scholarid'])['name'].first().reset_index()

# %%
data_4_no_dupes
# Out:
#                      affiliation  \
# 0       Wichita State University
# 1                           AUEB
# 2                           AUEB
# 3                           AUEB
# 4                           AUEB
# ...                          ...
# 20645         Özyeğin University
# 20646         Özyeğin University
# 20647         Özyeğin University
# 20648         Özyeğin University
# 20649         Özyeğin University
#
#                                                 homepage     scholarid  \
# 0      https://www.wichita.edu/profiles/academics/eng...  903CLcgAAAAJ
# 1            http://ieeexplore.ieee.org/document/4114886  WTg8mXoAAAAJ
# 2                        http://nes.aueb.gr/dimakis.html  DlAhQuIAAAAJ
# 3                       http://nes.aueb.gr/users/gs.html  5uRFCLsAAAAJ
# 4                              http://niovi.aueb.gr/~gcp  y-Mxxa0AAAAJ
# ...                                                  ...           ...
# ...

# %%
data_4_no_dupes_sort = data_4_no_dupes.sort_values(by = ['name'])

# %%
data_4_no_dupes_sort
# Out:
#                            affiliation  \
# 10556                          TU Wien
# 4795                              IUST
# 4892           Imperial College London
# 4354                     IIT Hyderabad
# 464                               BUET
# ...                                ...
# 11521                             UFMG
# 16555             University of Murcia
# 3653              Hacettepe University
# 685                 Bilkent University
# 3375   Georgia Institute of Technology
#
#                                                 homepage     scholarid  \
# 10556                   http://www.ifs.tuwien.ac.at/tjoa  x8qCMhcAAAAJ
# 4795   http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...  pCil4_cAAAAJ
# 4892          https://www.imperial.ac.uk/people/a.faisal  WjHjbrwAAAAJ
# 4354            http://www.iith.ac.in/~antony/index.html  LVfqLuoAAAAJ
# 464         https://sites.google.com/site/abmalimalislam  K-AIPzQAAAAJ
# ...

# %%
data_4_no_dupes_sort = data_4_no_dupes_sort.reset_index(drop = True)

# %%
data_4_no_dupes_sort
# Out:
#                            affiliation  \
# 0                              TU Wien
# 1                                 IUST
# 2              Imperial College London
# 3                        IIT Hyderabad
# 4                                 BUET
# ...                                ...
# 20645                             UFMG
# 20646             University of Murcia
# 20647             Hacettepe University
# 20648               Bilkent University
# 20649  Georgia Institute of Technology
#
#                                                 homepage     scholarid  \
# 0                       http://www.ifs.tuwien.ac.at/tjoa  x8qCMhcAAAAJ
# 1      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...  pCil4_cAAAAJ
# 2             https://www.imperial.ac.uk/people/a.faisal  WjHjbrwAAAAJ
# 3               http://www.iith.ac.in/~antony/index.html  LVfqLuoAAAAJ
# 4           https://sites.google.com/site/abmalimalislam  K-AIPzQAAAAJ
# ...

# %%
temp_data_names = data_4_no_dupes_sort['name'].drop_duplicates()

# %%
temp_data_names
# Out:
# 0                    A Min Tjoa
# 1             A. Akbari Azirani
# 2                A. Aldo Faisal
# 3            A. Antony Franklin
# 4        A. B. M. Alim Al Islam
#                   ...
# 20645               Ítalo Cunha
# 20646             Óscar Cánovas
# 20647              Özgür Erkent
# 20648              Özgür Ulusoy
# 20649        Ümit V. Çatalyürek
# Name: name, Length: 20650, dtype: object

# %%
data_3_no_dupes
# Out:
#                            affiliation  \
# 0                              TU Wien
# 1                                 IUST
# 3              Imperial College London
# 4                        IIT Hyderabad
# 5                                 BUET
# ...                                ...
# 25184  Georgia Institute of Technology
# 25185              New York University
# 25186    Weizmann Institute of Science
# 25187               University of Utah
# 25188    University of Texas at Dallas
#
#                                                 homepage      scholarid
# 0                       http://www.ifs.tuwien.ac.at/tjoa   x8qCMhcAAAAJ
# 1      http://ce.iust.ac.ir/page.php?slct_pg_id=6537&...   pCil4_cAAAAJ
# 3             https://www.imperial.ac.uk/people/a.faisal   WjHjbrwAAAAJ
# 4               http://www.iith.ac.in/~antony/index.html   LVfqLuoAAAAJ
# 5           https://sites.google.com/site/abmalimalislam   K-AIPzQAAAAJ
# ...

# %%
data_5= data.groupby(['affiliation', 'homepage', 'scholarid']).count()

# %%
data_5
# Out:
#                                                                                            name
# affiliation               homepage                                           scholarid
#  Wichita State University https://www.wichita.edu/profiles/academics/engi... 903CLcgAAAAJ     1
# AUEB                      http://ieeexplore.ieee.org/document/4114886        WTg8mXoAAAAJ     1
#                           http://nes.aueb.gr/dimakis.html                    DlAhQuIAAAAJ     1
#                           http://nes.aueb.gr/users/gs.html                   5uRFCLsAAAAJ     1
#                           http://niovi.aueb.gr/~gcp                          y-Mxxa0AAAAJ     1
# ...                                                                                         ...
# Özyeğin University        https://faculty.ozyegin.edu.tr/ismailakturk        B5hTe7sAAAAJ     1
#                           https://faculty.ozyegin.edu.tr/ismailari           00tvX_4AAAAJ     1
# ...

# %%
data_5.rename(columns={'name':'count'})
# Out:
#                                                                                            count
# affiliation               homepage                                           scholarid
#  Wichita State University https://www.wichita.edu/profiles/academics/engi... 903CLcgAAAAJ      1
# AUEB                      http://ieeexplore.ieee.org/document/4114886        WTg8mXoAAAAJ      1
#                           http://nes.aueb.gr/dimakis.html                    DlAhQuIAAAAJ      1
#                           http://nes.aueb.gr/users/gs.html                   5uRFCLsAAAAJ      1
#                           http://niovi.aueb.gr/~gcp                          y-Mxxa0AAAAJ      1
# ...                                                                                          ...
# Özyeğin University        https://faculty.ozyegin.edu.tr/ismailakturk        B5hTe7sAAAAJ      1
#                           https://faculty.ozyegin.edu.tr/ismailari           00tvX_4AAAAJ      1
# ...

# %%
data_6_no_dupes=data_5.merge( data, how='left', on=['affiliation', 'homepage', 'scholarid'])

# %%
data_6_no_dupes
# Out:
#                      affiliation  \
# 0       Wichita State University
# 1                           AUEB
# 2                           AUEB
# 3                           AUEB
# 4                           AUEB
# ...                          ...
# 25184         Özyeğin University
# 25185         Özyeğin University
# 25186         Özyeğin University
# 25187         Özyeğin University
# 25188         Özyeğin University
#
#                                                 homepage     scholarid  \
# 0      https://www.wichita.edu/profiles/academics/eng...  903CLcgAAAAJ
# 1            http://ieeexplore.ieee.org/document/4114886  WTg8mXoAAAAJ
# 2                        http://nes.aueb.gr/dimakis.html  DlAhQuIAAAAJ
# 3                       http://nes.aueb.gr/users/gs.html  5uRFCLsAAAAJ
# 4                              http://niovi.aueb.gr/~gcp  y-Mxxa0AAAAJ
# ...                                                  ...           ...
# ...

# %%
data_7 = data_6_no_dupes.groupby(['affiliation', 'homepage', 'scholarid'])['name_y'].first().reset_index()

# %%
data_7
# Out:
#                      affiliation  \
# 0       Wichita State University
# 1                           AUEB
# 2                           AUEB
# 3                           AUEB
# 4                           AUEB
# ...                          ...
# 20645         Özyeğin University
# 20646         Özyeğin University
# 20647         Özyeğin University
# 20648         Özyeğin University
# 20649         Özyeğin University
#
#                                                 homepage     scholarid  \
# 0      https://www.wichita.edu/profiles/academics/eng...  903CLcgAAAAJ
# 1            http://ieeexplore.ieee.org/document/4114886  WTg8mXoAAAAJ
# 2                        http://nes.aueb.gr/dimakis.html  DlAhQuIAAAAJ
# 3                       http://nes.aueb.gr/users/gs.html  5uRFCLsAAAAJ
# 4                              http://niovi.aueb.gr/~gcp  y-Mxxa0AAAAJ
# ...                                                  ...           ...
# ...
