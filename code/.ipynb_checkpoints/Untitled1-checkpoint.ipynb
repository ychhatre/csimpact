# %%
from cmath import isnan
import os
from random import random
import time
from typing import Any
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from csv import writer

# read the data from a file
data = pd.read_csv(os.getcwd().replace('code','') + "/data/cleaned_prof_data_v4.csv")

# initialize web driver for selenium
options = webdriver.ChromeOptions()
options.add_argument('--disable-blink-features=AutomationControlled')
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
driver.implicitly_wait(random() * 10)


def findMaxCitations(web_elements: list):
    indOfMax = 0
    maxVal = 0
    for i in range(len(web_elements)):
        val = int(web_elements[i].text.split(" - ")[2].split(" ")[2])
        if val > maxVal:
            maxVal = val
            indOfMax = i
        else:
            continue
    return web_elements[indOfMax]


# loop through and find all professors with wrong / no google scholar ID
professors = []
professorExists = True

time.sleep(60)

for i in range(4712, 5000):
    
    # initialize values
    scholar_id = data.iat[i, 3]
    citation = data.iat[i, 4]
    h_index = data.iat[i, 5]

    if (data.iat[i, 3] == "NOSCHOLARPAGE" or data.iat[i, 3] == "#NAME?" or isnan(data.iat[i, 4]) or isnan(data.iat[i, 5])):
        # launch URL
        driver.get("https://scholar.google.com")

        # identify search box
        box = driver.find_element(By.NAME, "q")

        # enter search text
        box.send_keys(data.iat[i, 0] + " " + data.iat[i, 1])

        # make search
        box.send_keys(Keys.ENTER)

        # in the case that the author pops up as a recommended option
        try:
            link = driver.find_element(
                By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]/h4/a")
            link.click()
            time.sleep(random() * 3)
            
        except:
            try:
                # in the case there are multiple options in the recommended table
                list_of_elements = driver.find_element(
                    By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]").find_elements(By.TAG_NAME, "div")
                max_element = findMaxCitations(list_of_elements)
                max_element.find_element(By.TAG_NAME, "a").click()
                time.sleep(random() * 5)
            except:
                # otherwise loop through all the divs and find the correct professor
                elements_list = driver.find_element(
                    By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]").find_element(By.CLASS_NAME, "gs_a").find_elements(By.TAG_NAME, "a")
                if elements_list: 
                    for element in elements_list:  # looping through the number of professors in the link
                        try:
                            element.find_element(By.TAG_NAME, "b")
                            element.click()
                            professorExists = True
                            break
                        except NoSuchElementException:
                            professorExists = False
                            continue  # in the case that the element is not found
                    # give time for html / css / js to load
                    time.sleep(random() * 5)
                else: 
                    professorExists = False 

        # retrieve citation, h-index, and scholar_id for that prof
        if professorExists:
            scholar_id = driver.current_url.split("=")[1].split("&")[0]
            citation = int(driver.find_element(
                By.XPATH, "//*[@id='gsc_rsb_st']/tbody/tr[1]/td[2]").text)
            h_index = int(driver.find_element(
                By.XPATH, "//*[@id='gsc_rsb_st']/tbody/tr[2]/td[2]").text)
            time.sleep(random() * 5)
        else:
            scholar_id = None
            citation = None
            h_index = None
    
    print(i)
    professor = { 
        "Name": data.iat[i, 0],
        "affiliation": data.iat[i, 1],
        "homepage": data.iat[i, 2],
        "scholar-id": scholar_id,
        "citations": citation,
        "h-index": h_index
    }
    print(professor)
    professors.append(professor)


df = pd.DataFrame(professors)
df.to_csv(os.getcwd().replace('code','') +"data/data2.csv", index = False)
# Out:
# [WDM] - ====== WebDriver manager ======
# 2022-08-02 14:06:14,539 INFO ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# 2022-08-02 14:06:14,615 INFO Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# 2022-08-02 14:06:14,617 INFO Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/kevins/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# 2022-08-02 14:06:14,844 INFO Driver [/Users/kevins/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_40413/4291703728.py:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# 4712
# {'Name': 'Kasper Støy', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/kasper-stoey(2a9c0934-98ca-4101-b829-b88d77f6487e).html', 'scholar-id': 's4I2aDgAAAAJ', 'citations': 3541, 'h-index': 30}
# 4713
# {'Name': 'Oliver Krancher', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/oliver-krancher(f14f4742-c9d8-4a34-b8e2-d713c3a1f437).html', 'scholar-id': '4EqBYO0AAAAJ', 'citations': 229.0, 'h-index': 10.0}
# 4714
# {'Name': 'Laurens Boer', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/laurens-boer(25a5a0d6-404b-419c-9502-b246525617a2).html', 'scholar-id': 'XssDfsgAAAAJ', 'citations': 479.0, 'h-index': 11.0}
# 4715
# {'Name': 'Hans-Joachim Backe', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/hansjoachim-backe(44c88dce-966d-46f3-88a8-2014e39197b9).html', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4716
# {'Name': 'Lars Rune Christensen', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/lars-rune-christensen(92f6c3f3-0ad2-40fc-b278-69170f87567d).html', 'scholar-id': 'JZ1V3H0AAAAJ', 'citations': 525.0, 'h-index': 13.0}
# 4717
# {'Name': 'Nico Wunderlich', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/nico-wunderlich(80356733-d435-4c10-b4b9-2878dcf57f1b).html', 'scholar-id': 'P5QGP40AAAAJ', 'citations': 111.0, 'h-index': 6.0}
# 4718
# {'Name': 'Søren Debois', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/soeren-debois(d3b41838-e2bf-4735-b1cd-03f60b49c7e5).html', 'scholar-id': 'okin7NMAAAAJ', 'citations': 1564.0, 'h-index': 19.0}
# 4719
# {'Name': 'Troels Bjerre Lund', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.itu.dk/people/trbj', 'scholar-id': '2tOriSoAAAAJ', 'citations': 621.0, 'h-index': 14.0}
# 4720
# {'Name': 'Philippe Bonnet', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.itu.dk/people/phbo', 'scholar-id': 'S9zyMRgAAAAJ', 'citations': 4892.0, 'h-index': 26.0}
# 4721
# {'Name': 'Rasmus Ejlers Møgelberg', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.itu.dk/people/mogel', 'scholar-id': 'MBiWoI8AAAAJ', 'citations': 981, 'h-index': 16}
# 4722
# {'Name': 'Jesper Bengtson', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.itu.dk/people/jebe', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4723
# {'Name': 'Peter Sestoft', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.itu.dk/people/sestoft', 'scholar-id': 'qz1BCu8AAAAJ', 'citations': 5231.0, 'h-index': 25.0}
# 4724
# {'Name': 'Helena Karasti', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/helena-karasti(fdbd5c94-bf35-463a-ab70-1224809bbbf4).html', 'scholar-id': 'oEzi1K0AAAAJ', 'citations': 2633.0, 'h-index': 23.0}
# 4725
# {'Name': 'Katrine Meldgaard Kjær', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/katrine-meldgaard-kjaer(0c46864b-a7f8-4439-aeda-0781f77bfe88).html', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4726
# {'Name': 'Helge Pfeiffer', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/helge-pfeiffer(51cfa226-5179-4a05-aa13-4a53f8de6404).html', 'scholar-id': '3_WyeYcAAAAJ', 'citations': 885.0, 'h-index': 15.0}
# 4727
# {'Name': 'Claus Brabrand', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://itu.dk/people/brabrand', 'scholar-id': 'oxk_o-UAAAAJ', 'citations': 1950.0, 'h-index': 24.0}
# 4728
# {'Name': 'Oksana Kulyk', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/oksana-kulyk(1dbd1112-eb47-4406-936c-6807e8845610).html', 'scholar-id': '08IyY1AAAAAJ', 'citations': 359.0, 'h-index': 11.0}
# 4729
# {'Name': 'Stefan Heinrich', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://stefanheinrich.net', 'scholar-id': 'hHx7vgoAAAAJ', 'citations': 517.0, 'h-index': 12.0}
# 4730
# {'Name': 'Henrique Debarba', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/henrique-galvan-debarba(4ac798ea-a458-473f-ba46-2e7515cf72e4).html', 'scholar-id': 'ZutRbb0AAAAJ', 'citations': 683.0, 'h-index': 16.0}
# 4731
# {'Name': 'Björn Þór Jónsson', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.itu.dk/people/bjth', 'scholar-id': 'syXaq1IAAAAJ', 'citations': 2271.0, 'h-index': 18.0}
# 4732
# {'Name': 'Roberta Sinatra', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://www.robertasinatra.com', 'scholar-id': 'PL8nGh4AAAAJ', 'citations': 3463.0, 'h-index': 23.0}
# 4733
# {'Name': 'Alessandro Bruni', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/alessandro-bruni(5c50bbc9-ed3d-417f-ba4d-e484eaf536b3).html', 'scholar-id': 'lbZ6n5IAAAAJ', 'citations': 21499.0, 'h-index': 62.0}
# 4734
# {'Name': 'Andrzej Wasowski', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.itu.dk/people/wasowski', 'scholar-id': 'GgpJrwMAAAAJ', 'citations': 7704.0, 'h-index': 44.0}
# 4735
# {'Name': 'Martin Aumüller', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/da/persons/martin-aumuller(5f52759c-418a-41b7-bbdb-050492677284).html', 'scholar-id': 'TNJYIYoAAAAJ', 'citations': 417.0, 'h-index': 10.0}
# 4736
# {'Name': 'Leon Derczynski', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/leon-derczynski(785a7089-e58e-4aaa-986d-ae0e615ba508).html', 'scholar-id': 'd8iwqa8AAAAJ', 'citations': 5039.0, 'h-index': 28.0}
# 4737
# {'Name': 'Luca Rossi', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/luca-rossi(1b45e3f5-b8cd-4c0d-a444-2901304f76ee).html', 'scholar-id': 'Vv1gFf0AAAAJ', 'citations': 1893.0, 'h-index': 24.0}
# 4738
# {'Name': 'Marco Carbone', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/marco-carbone(9027b41a-4159-4db7-9ddd-8fc8f41f1fb3).html', 'scholar-id': 'abe9klkAAAAJ', 'citations': 3954.0, 'h-index': 25.0}
# 4739
# {'Name': 'Lene Nielsen', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/lene-nielsen(1052b289-f510-4c5a-9662-2db48c12ebc2).html', 'scholar-id': 'NduaoNUAAAAJ', 'citations': 2228.0, 'h-index': 25.0}
# 4740
# {'Name': 'Sami S. Brandt', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://image.diku.dk/sbrandt', 'scholar-id': 'P7lhQ30AAAAJ', 'citations': 2416.0, 'h-index': 21.0}
# 4741
# {'Name': 'Michael Szell', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://michael.szell.net', 'scholar-id': '3kwJhIcAAAAJ', 'citations': 3419.0, 'h-index': 23.0}
# 4742
# {'Name': 'Mircea Filip Lungu', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/da/persons/mircea-lungu(02960d47-7677-4b2c-99d4-490a31fd6885).html', 'scholar-id': '7zx6Cg0AAAAJ', 'citations': 2231.0, 'h-index': 28.0}
# 4743
# {'Name': 'Willard Rafnsson', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/da/persons/willard-rafnsson(9cf737ee-bd9a-4f7e-b865-b6ff6ed01fde).html', 'scholar-id': 'LvbsGtkAAAAJ', 'citations': 190.0, 'h-index': 7.0}
# 4744
# {'Name': 'Giacomo Poderi', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/giacomo-poderi(534a54a6-fa36-466a-a1c1-461c54660bcc).html', 'scholar-id': 'PhnSRJwAAAAJ', 'citations': 161.0, 'h-index': 8.0}
# 4745
# {'Name': 'Natalie Schluter', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/natalie-elaine-schluter(879e7ac4-e64c-4c5f-9591-421e56cd0678).html', 'scholar-id': '9roj6ZEAAAAJ', 'citations': 459.0, 'h-index': 11.0}
# 4746
# {'Name': 'Baki Cakici', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/baki-cakici(b614ac6f-eefa-44a3-8b9a-092b88d86d37).html', 'scholar-id': '0UVuv_0AAAAJ', 'citations': 288.0, 'h-index': 11.0}
# 4747
# {'Name': 'Aske Mottelson', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/aske-mottelson(410df04c-bc1d-4cd3-9726-c35469ddab8c).html', 'scholar-id': 'TJ4FMD8AAAAJ', 'citations': 389.0, 'h-index': 12.0}
# 4748
# {'Name': 'Anna Vallgårda', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/anna-vallgaarda(2fa5dc89-7d78-45d0-96c7-e8f39b78dd3e).html', 'scholar-id': 'sRVXyvkAAAAJ', 'citations': 1337.0, 'h-index': 17.0}
# 4749
# {'Name': 'Andres Faina', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/andres-faina(7dd48cfe-3069-4563-bef4-ef661c18387a).html', 'scholar-id': 'KxfaneoAAAAJ', 'citations': 622.0, 'h-index': 14.0}
# 4750
# {'Name': 'Radu-Cristian Curticapean', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/da/persons/raducristian-curticapean(53c45a58-4c3c-424c-80a2-c39e733fd7c3).html', 'scholar-id': '5MeyUVQAAAAJ', 'citations': 458.0, 'h-index': 11.0}
# 4751
# {'Name': 'Therese Graversen', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/da/persons/therese-graversen(1578b20c-b5d0-466f-b114-2582529ddc53).html', 'scholar-id': 'Q5A51XMAAAAJ', 'citations': 179.0, 'h-index': 6.0}
# 4752
# {'Name': 'Michele Coscia', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/da/persons/michele-coscia(90b501a9-4d44-460b-b193-4d7d524bb21b).html', 'scholar-id': '3p_bhfUAAAAJ', 'citations': 4645.0, 'h-index': 23.0}
# 4753
# {'Name': 'Luca Maria Aiello', 'affiliation': 'IT University of Copenhagen', 'homepage': 'http://www.lajello.com', 'scholar-id': 'FIX-7hcAAAAJ', 'citations': 3970.0, 'h-index': 30.0}
# 4754
# {'Name': 'Anders Sundnes Løvlie', 'affiliation': 'IT University of Copenhagen', 'homepage': 'https://pure.itu.dk/portal/en/persons/anders-sundnes-loevlie(22ec9269-2fff-4dbf-a9c7-5037559a15ee).html', 'scholar-id': 'UhP1dScAAAAJ', 'citations': 374.0, 'h-index': 13.0}
# 4755
# {'Name': 'Gabriel Tsechpenakis', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/people/gavriil-tsechpenakis', 'scholar-id': 'y7uuI7gAAAAJ', 'citations': 749.0, 'h-index': 13.0}
# 4756
# {'Name': 'Rajeev R. Raje', 'affiliation': 'IUPUI', 'homepage': 'https://science.iupui.edu/people/raje-rajeev', 'scholar-id': 'kf7o8yAAAAAJ', 'citations': 1830.0, 'h-index': 23.0}
# 4757
# {'Name': 'Arjan Durresi', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~durresi', 'scholar-id': 'MrVb9FkAAAAJ', 'citations': 6644.0, 'h-index': 39.0}
# 4758
# {'Name': 'Murat Dundar', 'affiliation': 'IUPUI', 'homepage': 'http://cadkd.cs.iupui.edu', 'scholar-id': 'UvNbBnEAAAAJ', 'citations': 3384.0, 'h-index': 28.0}
# 4759
# {'Name': 'Mihran Tuceryan', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/people/mihran-tuceryan', 'scholar-id': 'F-o1I5wAAAAJ', 'citations': 6527.0, 'h-index': 27.0}
# 4760
# {'Name': 'George Mohler', 'affiliation': 'IUPUI', 'homepage': 'http://science.iupui.edu/people/george-mohler', 'scholar-id': 'J-vrZ58AAAAJ', 'citations': 3741.0, 'h-index': 25.0}
# 4761
# {'Name': 'Jiang Yu Zheng', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~jzheng', 'scholar-id': 'Gih-kpUAAAAJ', 'citations': 2807.0, 'h-index': 24.0}
# 4762
# {'Name': 'Shiaofen Fang', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~sfang', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4763
# {'Name': 'Yuni Xia', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~yxia', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4764
# {'Name': 'Xukai Zou', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~xkzou', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4765
# {'Name': 'Fengguang Song', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~fgsong', 'scholar-id': 'BoVnm1wAAAAJ', 'citations': 846.0, 'h-index': 14.0}
# 4766
# {'Name': 'Yao Liang', 'affiliation': 'IUPUI', 'homepage': 'https://science.iupui.edu/people/liang-yao', 'scholar-id': 'Pkod5TQAAAAJ', 'citations': 2221.0, 'h-index': 11.0}
# 4767
# {'Name': 'Aqueasha Martin-Hammond', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/aqueasha-martin-hammond', 'scholar-id': 'ldnCWNQAAAAJ', 'citations': 360.0, 'h-index': 11.0}
# 4768
# {'Name': 'Karl F. MacDorman', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/karl-macdorman', 'scholar-id': 'W-DuNjYAAAAJ', 'citations': 12177.0, 'h-index': 34.0}
# 4769
# {'Name': 'Andrew D Miller', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/andrew-miller', 'scholar-id': 'U5QeuUcAAAAJ', 'citations': 1695.0, 'h-index': 18.0}
# 4770
# {'Name': 'Mohammad Al Hasan', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~alhasan', 'scholar-id': 'fsCnri8AAAAJ', 'citations': 7673.0, 'h-index': 34.0}
# 4771
# {'Name': 'Lynn Dombrowski', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/lynn-dombrowski', 'scholar-id': 'ZCNrpS8AAAAJ', 'citations': 1570.0, 'h-index': 18.0}
# 4772
# {'Name': 'Khairi Reda', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/khairi-reda', 'scholar-id': 'sxXvVekAAAAJ', 'citations': 676.0, 'h-index': 14.0}
# 4773
# {'Name': 'Snehasis Mukhopadhyay', 'affiliation': 'IUPUI', 'homepage': 'http://cs.iupui.edu/~smukhopa', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4774
# {'Name': 'Francesco Cafaro', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/francesco-cafaro', 'scholar-id': 'gvdVQ7gAAAAJ', 'citations': 367.0, 'h-index': 11.0}
# 4775
# {'Name': 'Erin Brady', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/erin-brady', 'scholar-id': 'BAZIWBUAAAAJ', 'citations': 1326.0, 'h-index': 18.0}
# 4776
# {'Name': 'Davide Bolchini', 'affiliation': 'IUPUI', 'homepage': 'https://soic.iupui.edu/people/davide-bolchini', 'scholar-id': 'vUNp_gwAAAAJ', 'citations': 2331.0, 'h-index': 25.0}
# 4777
# {'Name': 'James H. Hill', 'affiliation': 'IUPUI', 'homepage': 'http://sebox.cs.iupui.edu', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4778
# {'Name': 'Mahdi Fazeli', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=11585&sid=14&slc_lang=en', 'scholar-id': 'XeHQnLMAAAAJ', 'citations': 1779.0, 'h-index': 23.0}
# 4779
# {'Name': 'Eynollah Khanjari', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/content/22145/Dr.Khanjari', 'scholar-id': '7o0YDzkAAAAJ', 'citations': 74.0, 'h-index': 6.0}
# 4780
# {'Name': 'Zeinab Movahedi', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/content/26538/Dr-Zeinab-Movahedi', 'scholar-id': '2179AKkAAAAJ', 'citations': 499.0, 'h-index': 11.0}
# 4781
# {'Name': 'A. Akbari Azirani', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=6537&sid=14&slc_lang=en', 'scholar-id': 'pCil4_cAAAAJ', 'citations': 1326.0, 'h-index': 18.0}
# 4782
# {'Name': 'Hakem Beitollahi', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=18185&sid=14&slc_lang=en', 'scholar-id': 'SMnMHbQAAAAJ', 'citations': 725.0, 'h-index': 15.0}
# 4783
# {'Name': 'Mehrdad Ashtiani', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/page.php?slct_pg_id=18184&sid=14&slc_lang=en', 'scholar-id': 'dsdZaDAAAAAJ', 'citations': 272.0, 'h-index': 9.0}
# 4784
# {'Name': 'Mohammad Reza Mohammadi', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=18188&sid=14&slc_lang=en', 'scholar-id': 'H34y7Q0AAAAJ', 'citations': 325.0, 'h-index': 9.0}
# 4785
# {'Name': 'Vesal Hakami', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/page.php?slct_pg_id=18186&sid=14&slc_lang=en', 'scholar-id': 'l3D_gCAAAAAJ', 'citations': 245.0, 'h-index': 9.0}
# 4786
# {'Name': 'Mohammad Abdollahi Azgomi', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/content/8313/Dr.-Abdollahi-Azgomi', 'scholar-id': 'OcWAFjcAAAAJ', 'citations': 1883.0, 'h-index': 24.0}
# 4787
# {'Name': 'Mahmoud Fathy', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/579/Mahmoud-Fathy', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4788
# {'Name': 'Behrooz Minaei', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/544/Dr.-Behrouz-Minaei', 'scholar-id': 'M8tgU-wAAAAJ', 'citations': 5752.0, 'h-index': 37.0}
# 4789
# {'Name': 'Saeed Parsa', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/page.php?slct_pg_id=717&sid=14&slc_lang=en', 'scholar-id': 'uONxvOwAAAAJ', 'citations': 1404.0, 'h-index': 17.0}
# 4790
# {'Name': 'Mohsen Soryani', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/527/Mohsen-Soryani', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4791
# {'Name': 'Hassan Naderi', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/content/18922/Dr.-Naderi', 'scholar-id': '-47I2ZIAAAAJ', 'citations': 260.0, 'h-index': 8.0}
# 4792
# {'Name': 'Sauleh Eetemadi', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=18192&sid=14&slc_lang=en', 'scholar-id': 'Q25s5KkAAAAJ', 'citations': 154.0, 'h-index': 7.0}
# 4793
# {'Name': 'Mohsen Sharifi', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=6531&sid=14&slc_lang=en', 'scholar-id': 'lboyQG8AAAAJ', 'citations': 3131.0, 'h-index': 26.0}
# 4794
# {'Name': 'Morteza Analoui', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/580/welcome-you-to-his-web-page', 'scholar-id': 'WN82kZoAAAAJ', 'citations': 1221.0, 'h-index': 19.0}
# 4795
# {'Name': 'Peyman Kabiri', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/582/Peyman-Kabiri', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4796
# {'Name': 'Reza Entezari-Maleki', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=18357&sid=14&slc_lang=en', 'scholar-id': 'nOx3MnAAAAAJ', 'citations': 979.0, 'h-index': 15.0}
# 4797
# {'Name': 'Amir Mahdi Hosseini Monazzah', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/page.php?slct_pg_id=18700&sid=14&slc_lang=en', 'scholar-id': 'C4yrITAAAAAJ', 'citations': 501.0, 'h-index': 14.0}
# 4798
# {'Name': 'Mohammad Reza Jahed-Motlagh', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/1049/Dr.-Jahed-Motlagh', 'scholar-id': 'i5G246QAAAAJ', 'citations': 2424.0, 'h-index': 24.0}
# 4799
# {'Name': 'Reza Berangi', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/content/1074/Berangi-Reza.-PH.D', 'scholar-id': 'A030YlYAAAAJ', 'citations': 932.0, 'h-index': 16.0}
# 4800
# {'Name': 'Adel Rahmani', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/content/18919/Dr.Torkaman-Rahmani', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4801
# {'Name': 'Naser Mozayani', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/583/Dr-mozayani', 'scholar-id': 'LAAM5tEAAAAJ', 'citations': 1532.0, 'h-index': 20.0}
# 4802
# {'Name': 'Sayed Vahid Azhari', 'affiliation': 'IUST', 'homepage': 'http://ce.iust.ac.ir/content/7755/Dr.-Azhari', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4803
# {'Name': 'Mohammad Reza Kangavari', 'affiliation': 'IUST', 'homepage': 'http://www.iust.ac.ir/content/1064/Dr.Kangavari', 'scholar-id': 'PJa-dVMAAAAJ', 'citations': 751.0, 'h-index': 14.0}
# 4804
# {'Name': 'Edward M. Reingold', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/edward-reingold', 'scholar-id': 'UlQeH7AAAAAJ', 'citations': 13000.0, 'h-index': 28.0}
# 4805
# {'Name': 'Bogdan Korel', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/bogdan-korel', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4806
# {'Name': 'Peng-Jun Wan', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/peng-jun-wan', 'scholar-id': 'TXUhDokAAAAJ', 'citations': 12886.0, 'h-index': 54.0}
# 4807
# {'Name': 'Xian-He Sun', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/xian-he-sun', 'scholar-id': '9h3JX7MAAAAJ', 'citations': 7989.0, 'h-index': 45.0}
# 4808
# {'Name': 'Eunice E. Santos', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/eunice-santos', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4809
# {'Name': 'Shangping Ren', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/shangping-ren', 'scholar-id': 'jX0ar6QAAAAJ', 'citations': 1901, 'h-index': 22}
# 4810
# {'Name': 'Sanjiv Kapoor', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/sanjiv-kapoor', 'scholar-id': '5KwApbgAAAAJ', 'citations': 2346.0, 'h-index': 26.0}
# 4811
# {'Name': 'Kai Shu', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'http://www.cs.iit.edu/~kshu', 'scholar-id': '-6bAV2cAAAAJ', 'citations': 5807.0, 'h-index': 27.0}
# 4812
# {'Name': 'Lance Fortnow', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'http://www.cc.gatech.edu/people/lance-fortnow', 'scholar-id': 'Yf5wVssAAAAJ', 'citations': 10446.0, 'h-index': 46.0}
# 4813
# {'Name': 'Cynthia Hood', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/cynthia-hood', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4814
# {'Name': 'Sean P. Engelson', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/shlomo-argamon', 'scholar-id': 'mjsJxhQAAAAJ', 'citations': 11543.0, 'h-index': 42.0}
# 4815
# {'Name': 'Rujia Wang', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://rujiawang.github.io', 'scholar-id': 'IbOb-M4AAAAJ', 'citations': 283.0, 'h-index': 8.0}
# 4816
# {'Name': 'Zhiling Lan', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/zhiling-lan', 'scholar-id': 'WZVDjawAAAAJ', 'citations': 3282.0, 'h-index': 33.0}
# 4817
# {'Name': 'Yan Yan', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://www.iit.edu/directory/people/yan-yan', 'scholar-id': 'zhi-j1wAAAAJ', 'citations': 5173.0, 'h-index': 36.0}
# 4818
# {'Name': 'Gady Agam', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/gady-agam', 'scholar-id': '0wKmvY0AAAAJ', 'citations': 1916.0, 'h-index': 22.0}
# 4819
# {'Name': 'Ioan Raicu', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/ioan-raicu', 'scholar-id': 'jE73HYAAAAAJ', 'citations': 12095.0, 'h-index': 45.0}
# 4820
# {'Name': 'Yue Duan', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://yueduan.github.io', 'scholar-id': 'q3rLf5kAAAAJ', 'citations': 1002.0, 'h-index': 11.0}
# 4821
# {'Name': 'Yuan Hong', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/yuan-hong', 'scholar-id': 'KJuZW2wAAAAJ', 'citations': 1489, 'h-index': 21}
# 4822
# {'Name': 'Gruia Calinescu', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/gruia-calinescu', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4823
# {'Name': 'Dong Jin', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/kevin-jin', 'scholar-id': '-ln1Vp0AAAAJ', 'citations': 1395, 'h-index': 20}
# 4824
# {'Name': 'Mustafa Bilgic', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/mustafa-bilgic', 'scholar-id': 'bOM9qN8AAAAJ', 'citations': 4091.0, 'h-index': 19.0}
# 4825
# {'Name': 'Boris Glavic', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/boris-glavic', 'scholar-id': 'lCdBR8cAAAAJ', 'citations': 1547.0, 'h-index': 21.0}
# 4826
# {'Name': 'Stefan K. Muller', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'http://www.cs.iit.edu/~smuller', 'scholar-id': 'vM6V_aMAAAAJ', 'citations': 145.0, 'h-index': 6.0}
# 4827
# {'Name': 'Kyle C. Hale', 'affiliation': 'Illinois Institute of Technology', 'homepage': 'https://science.iit.edu/people/faculty/kyle-hale', 'scholar-id': 'zYAOJqwAAAAJ', 'citations': 196.0, 'h-index': 8.0}
# 4828
# {'Name': 'Dario Paccagnan', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~dp414', 'scholar-id': 'Y7wBGG8AAAAJ', 'citations': 415.0, 'h-index': 10.0}
# 4829
# {'Name': 'Stephen H. Muggleton', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/shm', 'scholar-id': 'WxJXT2MAAAAJ', 'citations': 20319.0, 'h-index': 73.0}
# 4830
# {'Name': 'Emil C. Lupu', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/e.c.lupu', 'scholar-id': 'e23mVyoAAAAJ', 'citations': 10455.0, 'h-index': 48.0}
# 4831
# {'Name': 'Antonio Filieri', 'affiliation': 'Imperial College London', 'homepage': 'http://www.antonio.filieri.name', 'scholar-id': 'MdbPRwMAAAAJ', 'citations': 2074.0, 'h-index': 23.0}
# 4832
# {'Name': 'Cristiano Calcagno', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/collegedirectory/index.asp?PeopleID=767740', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4833
# {'Name': 'Alessandra Russo', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/a.russo', 'scholar-id': '_6zceo4AAAAJ', 'citations': 4783.0, 'h-index': 35.0}
# 4834
# {'Name': 'Andrew J. Davison', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~ajd', 'scholar-id': 'MrI1EV4AAAAJ', 'citations': 4585, 'h-index': 27}
# 4835
# {'Name': 'Abbas Edalat', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~ae', 'scholar-id': 'KP1AXgwAAAAJ', 'citations': 2930.0, 'h-index': 24.0}
# 4836
# {'Name': 'Murray Shanahan', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~mpsha', 'scholar-id': '00bnGpAAAAAJ', 'citations': 9928.0, 'h-index': 47.0}
# 4837
# {'Name': 'Alastair F. Donaldson', 'affiliation': 'Imperial College London', 'homepage': 'http://multicore.doc.ic.ac.uk', 'scholar-id': 'ZIUuqNwAAAAJ', 'citations': 2988.0, 'h-index': 32.0}
# 4838
# {'Name': 'Lluís Vilanova', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~lvilanov', 'scholar-id': 'aMMzgPoAAAAJ', 'citations': 685.0, 'h-index': 11.0}
# 4839
# {'Name': 'Wayne Luk', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~wl', 'scholar-id': 'F1JYd9UAAAAJ', 'citations': 35560.0, 'h-index': 91.0}
# 4840
# {'Name': 'Peter Pietzuch', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~prp', 'scholar-id': 'vYcHYoYAAAAJ', 'citations': 9119.0, 'h-index': 47.0}
# 4841
# {'Name': 'Philippa Gardner', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~pg', 'scholar-id': 'LDe0mUwAAAAJ', 'citations': 2969.0, 'h-index': 29.0}
# 4842
# {'Name': 'Nobuko Yoshida', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~yoshida', 'scholar-id': '4T-p76AAAAAJ', 'citations': 11413.0, 'h-index': 59.0}
# 4843
# {'Name': 'Iain C. C. Phillips', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/collegedirectory/index.asp?PeopleID=941691', 'scholar-id': 'LWUnAo4AAAAJ', 'citations': 1339, 'h-index': 20}
# 4844
# {'Name': 'Susan Eisenbach', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/s.eisenbach', 'scholar-id': 'fpMB-WYAAAAJ', 'citations': 3369.0, 'h-index': 26.0}
# 4845
# {'Name': 'Ben Glocker', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/bglocker', 'scholar-id': 'g_HtjLIAAAAJ', 'citations': 24100.0, 'h-index': 64.0}
# 4846
# {'Name': 'Julie A. McCann', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/aese/person/julie-a-mccann', 'scholar-id': 'S6wyzdwAAAAJ', 'citations': 6774.0, 'h-index': 35.0}
# 4847
# {'Name': 'Cristian Cadar', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~cristic', 'scholar-id': 'xQPpd1wAAAAJ', 'citations': 9907.0, 'h-index': 28.0}
# 4848
# {'Name': 'Daniel Rueckert', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/dr', 'scholar-id': 'H0O0WnQAAAAJ', 'citations': 69275.0, 'h-index': 118.0}
# 4849
# {'Name': 'Björn W. Schuller', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~bschulle', 'scholar-id': 'TxKNCSoAAAAJ', 'citations': 46302.0, 'h-index': 97.0}
# 4850
# {'Name': 'Francesco Belardinelli', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~fbelard', 'scholar-id': 'Mr35r1EAAAAJ', 'citations': 937.0, 'h-index': 13.0}
# 4851
# {'Name': 'Sergio Maffeis', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~maffeis', 'scholar-id': 'ODKP7a0AAAAJ', 'citations': 2237.0, 'h-index': 20.0}
# 4852
# {'Name': 'Holger Pirk', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~hlgr', 'scholar-id': '1jP_gqcAAAAJ', 'citations': 1065.0, 'h-index': 15.0}
# 4853
# {'Name': 'Bernhard Kainz', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/b.kainz', 'scholar-id': 'Igxq-YEAAAAJ', 'citations': 8256.0, 'h-index': 37.0}
# 4854
# {'Name': 'John Knottenbelt', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/w.knottenbelt', 'scholar-id': 'Vz8XWRoAAAAJ', 'citations': 5781.0, 'h-index': 41.0}
# 4855
# {'Name': 'Guang-Zhong Yang', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/g.z.yang', 'scholar-id': 'CuMvFDUAAAAJ', 'citations': 6409, 'h-index': 37}
# 4856
# {'Name': 'Nicholas R. Jennings', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/n.jennings', 'scholar-id': 'FX5CsuYAAAAJ', 'citations': 90955, 'h-index': 131}
# 4857
# {'Name': 'Peter G. Harrison', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/p.harrison', 'scholar-id': 'f6GUPSUAAAAJ', 'citations': 14129.0, 'h-index': 54.0}
# 4858
# {'Name': 'Stefanos P. Zafeiriou', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/s.zafeiriou', 'scholar-id': 'QKOH5iYAAAAJ', 'citations': 21246.0, 'h-index': 65.0}
# 4859
# {'Name': 'Iddo Tzameret', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~itzamere', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4860
# {'Name': 'A. J. Field', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/ajf', 'scholar-id': 'rn3Lg2wAAAAJ', 'citations': 3787.0, 'h-index': 15.0}
# 4861
# {'Name': 'Yi-Ke Guo', 'affiliation': 'Imperial College London', 'homepage': 'http://www.imperial.ac.uk/people/y.guo', 'scholar-id': '-0q6cIYAAAAJ', 'citations': 13886.0, 'h-index': 58.0}
# 4862
# {'Name': 'Naranker Dulay', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/nd', 'scholar-id': 'KXfVZq0AAAAJ', 'citations': 8116.0, 'h-index': 38.0}
# 4863
# {'Name': 'Azalea Raad', 'affiliation': 'Imperial College London', 'homepage': 'http://www.soundandcomplete.org', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4864
# {'Name': 'Paul H. J. Kelly', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/people/p.kelly', 'scholar-id': 'GIDpay0AAAAJ', 'citations': 17271.0, 'h-index': 58.0}
# 4865
# {'Name': 'Fariba Sadri', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~fs', 'scholar-id': '1CN_q7kAAAAJ', 'citations': 4401.0, 'h-index': 31.0}
# 4866
# {'Name': 'Michael Huth', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~mrh', 'scholar-id': 'ZBlUaIAAAAAJ', 'citations': 4606.0, 'h-index': 22.0}
# 4867
# {'Name': 'Mario Berta', 'affiliation': 'Imperial College London', 'homepage': 'http://marioberta.info', 'scholar-id': 'pc_5htgAAAAJ', 'citations': 4087.0, 'h-index': 30.0}
# 4868
# {'Name': 'Alessio Lomuscio', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~alessio', 'scholar-id': 'xdWZkEEAAAAJ', 'citations': 8490.0, 'h-index': 43.0}
# 4869
# {'Name': 'Francesca Toni', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~ft', 'scholar-id': 'L9dwO2cAAAAJ', 'citations': 10288.0, 'h-index': 47.0}
# 4870
# {'Name': 'Jeff Kramer', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/jk', 'scholar-id': 't-fuDjMAAAAJ', 'citations': 25830.0, 'h-index': 68.0}
# 4871
# {'Name': 'Dalal Alrajeh', 'affiliation': 'Imperial College London', 'homepage': 'https://www.doc.ic.ac.uk/~da04', 'scholar-id': 'onAoWhIAAAAJ', 'citations': 611.0, 'h-index': 13.0}
# 4872
# {'Name': 'Thomas Heinis', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/theinis', 'scholar-id': 'yJ998VYAAAAJ', 'citations': 2178.0, 'h-index': 17.0}
# 4873
# {'Name': 'Giuliano Casale', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/gcasale', 'scholar-id': 'Os1VLoQAAAAJ', 'citations': 4570.0, 'h-index': 36.0}
# 4874
# {'Name': 'Peter McBrien', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~pjm', 'scholar-id': 'VVV8tSwAAAAJ', 'citations': 1847.0, 'h-index': 22.0}
# 4875
# {'Name': 'Lucia Specia', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/lspecia', 'scholar-id': 'wVl_z8kAAAAJ', 'citations': 13000.0, 'h-index': 50.0}
# 4876
# {'Name': 'Kin K. Leung', 'affiliation': 'Imperial College London', 'homepage': 'http://www.commsp.ee.ic.ac.uk/~kkleung', 'scholar-id': 'IpG80kwAAAAJ', 'citations': 18735.0, 'h-index': 67.0}
# 4877
# {'Name': 'Panos Parpas', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~pp500', 'scholar-id': 'yXcvHysAAAAJ', 'citations': 1171.0, 'h-index': 21.0}
# 4878
# {'Name': 'Sophia Drossopoulou', 'affiliation': 'Imperial College London', 'homepage': 'https://wp.doc.ic.ac.uk/sd', 'scholar-id': '5g4VizIAAAAJ', 'citations': 4261.0, 'h-index': 34.0}
# 4879
# {'Name': 'Marek Rei', 'affiliation': 'Imperial College London', 'homepage': 'https://www.marekrei.com', 'scholar-id': 'nNeD95EAAAAJ', 'citations': 1494.0, 'h-index': 18.0}
# 4880
# {'Name': 'Antoine Cully', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/people/a.cully', 'scholar-id': 'rZtJlPQAAAAJ', 'citations': 2007.0, 'h-index': 17.0}
# 4881
# {'Name': 'Soteris Demetriou', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/computing/people/academic-staff', 'scholar-id': '4utItXUAAAAJ', 'citations': 1072.0, 'h-index': 11.0}
# 4882
# {'Name': 'Steffen van Bakel', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~svb', 'scholar-id': 'wSUVpA0AAAAJ', 'citations': 1355.0, 'h-index': 18.0}
# 4883
# {'Name': 'Arthur Gervais', 'affiliation': 'Imperial College London', 'homepage': 'http://arthurgervais.com', 'scholar-id': 'jLr_xi4AAAAJ', 'citations': 5208.0, 'h-index': 21.0}
# 4884
# {'Name': 'Herbert Wiklicky', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~herbert', 'scholar-id': '6Uh6z5AAAAAJ', 'citations': 1110.0, 'h-index': 17.0}
# 4885
# {'Name': 'Morris Sloman', 'affiliation': 'Imperial College London', 'homepage': 'http://wp.doc.ic.ac.uk/mss', 'scholar-id': 'ey299DUAAAAJ', 'citations': 16213.0, 'h-index': 56.0}
# 4886
# {'Name': 'Ruth Misener', 'affiliation': 'Imperial College London', 'homepage': 'https://wp.doc.ic.ac.uk/rmisener', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4887
# {'Name': 'Mark van der Wilk', 'affiliation': 'Imperial College London', 'homepage': 'https://markvdw.github.io', 'scholar-id': 'PKcjcT4AAAAJ', 'citations': 1793.0, 'h-index': 17.0}
# 4888
# {'Name': 'Abhijeet Ghosh', 'affiliation': 'Imperial College London', 'homepage': 'http://www.doc.ic.ac.uk/~ghosh', 'scholar-id': 'EG_UZvwAAAAJ', 'citations': 3261.0, 'h-index': 28.0}
# 4889
# {'Name': 'Maja Pantic', 'affiliation': 'Imperial College London', 'homepage': 'http://www.ibug.doc.ic.ac.uk/maja', 'scholar-id': 'ygpxbK8AAAAJ', 'citations': 42910.0, 'h-index': 95.0}
# 4890
# {'Name': 'Yves-Alexandre de Montjoye', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/computing/people/academic-staff', 'scholar-id': 'LVJtdoEAAAAJ', 'citations': 6353.0, 'h-index': 23.0}
# 4891
# {'Name': 'A. Aldo Faisal', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/people/a.faisal', 'scholar-id': 'WjHjbrwAAAAJ', 'citations': 6780.0, 'h-index': 31.0}
# 4892
# {'Name': 'Edward David Johns', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/people/e.johns', 'scholar-id': 'dHec-LkAAAAJ', 'citations': 2179.0, 'h-index': 18.0}
# 4893
# {'Name': 'Michael Bronstein', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/people/m.bronstein', 'scholar-id': 'UU3N6-UAAAAJ', 'citations': 25550.0, 'h-index': 71.0}
# 4894
# {'Name': 'Nicolas Wu', 'affiliation': 'Imperial College London', 'homepage': 'https://www.imperial.ac.uk/people/n.wu', 'scholar-id': '0E8zPucAAAAJ', 'citations': 524.0, 'h-index': 12.0}
# 4895
# {'Name': 'Yingzhen Li', 'affiliation': 'Imperial College London', 'homepage': 'http://yingzhenli.net/home/en/?page_id=345', 'scholar-id': 'gcfs8N8AAAAJ', 'citations': 2169.0, 'h-index': 18.0}
# 4896
# {'Name': 'László Egri', 'affiliation': 'Indiana State University', 'homepage': 'http://cs.indstate.edu/~legri', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4897
# {'Name': 'Yongsheng Bai', 'affiliation': 'Indiana State University', 'homepage': 'http://isu.indstate.edu/ybai2', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4898
# {'Name': 'Arash Rafiey', 'affiliation': 'Indiana State University', 'homepage': 'http://cs.indstate.edu/info/people.php', 'scholar-id': 'eJEmXiQAAAAJ', 'citations': 1049.0, 'h-index': 18.0}
# 4899
# {'Name': 'Jeff Kinne', 'affiliation': 'Indiana State University', 'homepage': 'https://www.indstate.edu/faculty-staff/jeffrey-kinne', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4900
# {'Name': 'Dana Habeeb', 'affiliation': 'Indiana University', 'homepage': 'http://danahabeeb.com', 'scholar-id': 'vVlyWw0AAAAJ', 'citations': 672.0, 'h-index': 5.0}
# 4901
# {'Name': 'Thomas L. Sterling', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=303', 'scholar-id': 'iaP4C54AAAAJ', 'citations': 8581, 'h-index': 39}
# 4902
# {'Name': 'Erik Stolterman', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=305', 'scholar-id': 'iotMZFMAAAAJ', 'citations': 11236.0, 'h-index': 44.0}
# 4903
# {'Name': 'David J. Wild', 'affiliation': 'Indiana University', 'homepage': 'http://david-wild-knzl.squarespace.com', 'scholar-id': '-0YOKRoAAAAJ', 'citations': 2619, 'h-index': 26}
# 4904
# {'Name': 'Martin A. Siegel', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=298', 'scholar-id': 'sZ_nSuIAAAAJ', 'citations': 1014.0, 'h-index': 17.0}
# 4905
# {'Name': 'Steven A. Myers', 'affiliation': 'Indiana University', 'homepage': 'http://wphomes.soic.indiana.edu/samyers', 'scholar-id': 'SQnCsswAAAAJ', 'citations': 2626.0, 'h-index': 23.0}
# 4906
# {'Name': 'Yuan Zhou', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=442', 'scholar-id': 'aR34e1gAAAAJ', 'citations': 10480.0, 'h-index': 24.0}
# 4907
# {'Name': 'Kahyun Choi', 'affiliation': 'Indiana University', 'homepage': 'http://kahyunchoi.com', 'scholar-id': 'TYXfH1wAAAAJ', 'citations': 218.0, 'h-index': 9.0}
# 4908
# {'Name': 'Cassidy R. Sugimoto', 'affiliation': 'Indiana University', 'homepage': 'https://ella.sice.indiana.edu/~sugimoto/index.php', 'scholar-id': 'AjKdHVMAAAAJ', 'citations': 11499.0, 'h-index': 49.0}
# 4909
# {'Name': 'Cenk S. Sahinalp', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=291', 'scholar-id': 'O8wbTncAAAAJ', 'citations': 22625, 'h-index': 57}
# 4910
# {'Name': 'D. Martin Swany', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=307', 'scholar-id': 'QwTp-V8AAAAJ', 'citations': 3309, 'h-index': 28}
# 4911
# {'Name': 'Damir Cavar', 'affiliation': 'Indiana University', 'homepage': 'http://damir.cavar.me', 'scholar-id': '6b8TO4cAAAAJ', 'citations': 1213.0, 'h-index': 16.0}
# 4912
# {'Name': 'Allen B. Riddell', 'affiliation': 'Indiana University', 'homepage': 'https://www.ariddell.org', 'scholar-id': 'zDIvI1UAAAAJ', 'citations': 5566.0, 'h-index': 7.0}
# 4913
# {'Name': 'Vikram Jadhao', 'affiliation': 'Indiana University', 'homepage': 'https://jadhaolab.engineering.indiana.edu', 'scholar-id': '7m5wqk4AAAAJ', 'citations': 614.0, 'h-index': 15.0}
# 4914
# {'Name': 'Johan Bollen', 'affiliation': 'Indiana University', 'homepage': 'https://homes.luddy.indiana.edu/jbollen', 'scholar-id': 'jDmcdsUAAAAJ', 'citations': 16093.0, 'h-index': 42.0}
# 4915
# {'Name': 'Zoran Tiganj', 'affiliation': 'Indiana University', 'homepage': 'https://homes.luddy.indiana.edu/ztiganj', 'scholar-id': 'BrWVCo8AAAAJ', 'citations': 799, 'h-index': 13}
# 4916
# {'Name': 'Katie A. Siek', 'affiliation': 'Indiana University', 'homepage': 'http://wphomes.soic.indiana.edu/ksiek', 'scholar-id': '-R9W7IkAAAAJ', 'citations': 3097.0, 'h-index': 31.0}
# 4917
# {'Name': 'Justin Wood', 'affiliation': 'Indiana University', 'homepage': 'http://buildingamind.com', 'scholar-id': 'q9EK5i0AAAAJ', 'citations': 2002.0, 'h-index': 25.0}
# 4918
# {'Name': 'Kay Connelly', 'affiliation': 'Indiana University', 'homepage': 'http://wphomes.soic.indiana.edu/connelly', 'scholar-id': 'uZZ7HtIAAAAJ', 'citations': 4261.0, 'h-index': 37.0}
# 4919
# {'Name': 'Robert D. Montoya', 'affiliation': 'Indiana University', 'homepage': 'http://robertdmontoya.com', 'scholar-id': 'JwuWrxkAAAAJ', 'citations': 47.0, 'h-index': 4.0}
# 4920
# {'Name': 'James A. Glazier', 'affiliation': 'Indiana University', 'homepage': 'https://iubphys.sitehost.iu.edu/faculty/glazier.shtml', 'scholar-id': 'y0pmefMAAAAJ', 'citations': 13236.0, 'h-index': 61.0}
# 4921
# {'Name': 'Lawrence S. Moss', 'affiliation': 'Indiana University', 'homepage': 'https://iulg.sitehost.iu.edu/moss', 'scholar-id': '9XDfKqYAAAAJ', 'citations': 5745.0, 'h-index': 30.0}
# 4922
# {'Name': 'Shuang Wang', 'affiliation': 'Indiana University', 'homepage': 'http://www.shuangwang.org', 'scholar-id': 'GnDGqKQAAAAJ', 'citations': 4421.0, 'h-index': 31.0}
# 4923
# {'Name': 'Bernard D. Frischer', 'affiliation': 'Indiana University', 'homepage': 'http://frischer.org', 'scholar-id': 'rehhrNQAAAAJ', 'citations': 2202, 'h-index': 25}
# 4924
# {'Name': 'Minje Kim', 'affiliation': 'Indiana University', 'homepage': 'https://minjekim.com', 'scholar-id': 'hEfnFKAAAAAJ', 'citations': 2446.0, 'h-index': 19.0}
# 4925
# {'Name': 'Luis Mateus Rocha', 'affiliation': 'Indiana University', 'homepage': 'https://homes.luddy.indiana.edu/rocha', 'scholar-id': 'SIouE70AAAAJ', 'citations': 5129.0, 'h-index': 31.0}
# 4926
# {'Name': 'Hamid R. Ekbia', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=72', 'scholar-id': 'WPGTvh8AAAAJ', 'citations': 1914.0, 'h-index': 21.0}
# 4927
# {'Name': 'David B. Leake', 'affiliation': 'Indiana University', 'homepage': 'https://www.cs.indiana.edu/~leake', 'scholar-id': 'CidT-JAAAAAJ', 'citations': 8984.0, 'h-index': 49.0}
# 4928
# {'Name': 'James Clawson', 'affiliation': 'Indiana University', 'homepage': 'https://jamesclawson.com', 'scholar-id': '7Z-F_AoAAAAJ', 'citations': 1914.0, 'h-index': 21.0}
# 4929
# {'Name': 'Paul W. Purdom', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~pwp', 'scholar-id': 'h6Z8WS0AAAAJ', 'citations': 3231.0, 'h-index': 27.0}
# 4930
# {'Name': 'Beth A. Plale', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~plale', 'scholar-id': 'CyGvFJkAAAAJ', 'citations': 7804.0, 'h-index': 41.0}
# 4931
# {'Name': 'Julie Fukuyama', 'affiliation': 'Indiana University', 'homepage': 'https://jfukuyama.github.io', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4932
# {'Name': 'Apu Kapadia', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~kapadia', 'scholar-id': 'r42-hFIAAAAJ', 'citations': 6350.0, 'h-index': 41.0}
# 4933
# {'Name': 'David J. Crandall', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~djcran', 'scholar-id': '8bQRH5YAAAAJ', 'citations': 10261.0, 'h-index': 47.0}
# 4934
# {'Name': 'Yuzhen Ye', 'affiliation': 'Indiana University', 'homepage': 'http://mendel.informatics.indiana.edu/~yye/lab', 'scholar-id': 'fH_ea0kAAAAJ', 'citations': 19955.0, 'h-index': 36.0}
# 4935
# {'Name': 'Andrew Womack', 'affiliation': 'Indiana University', 'homepage': 'http://pages.iu.edu/~ajwomack', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4936
# {'Name': 'John C. Paolillo', 'affiliation': 'Indiana University', 'homepage': 'http://paolillo.soic.indiana.edu', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4937
# {'Name': 'Gregory J. E. Rawlins', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~rawlins', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4938
# {'Name': 'Daniel Leivant', 'affiliation': 'Indiana University', 'homepage': 'https://www.cs.indiana.edu/~leivant', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4939
# {'Name': 'Raquel Hill', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~ralhill', 'scholar-id': 'kBNKU1YAAAAJ', 'citations': 282.0, 'h-index': 7.0}
# 4940
# {'Name': 'Dirk Van Gucht', 'affiliation': 'Indiana University', 'homepage': 'https://www.cs.indiana.edu/~vgucht', 'scholar-id': 'NCQuZX0AAAAJ', 'citations': 5867.0, 'h-index': 36.0}
# 4941
# {'Name': 'Eduardo J. Izquierdo', 'affiliation': 'Indiana University', 'homepage': 'http://mypage.iu.edu/~edizquie', 'scholar-id': 'KWCQjl0AAAAJ', 'citations': 903.0, 'h-index': 15.0}
# 4942
# {'Name': 'Patrick C. Shih', 'affiliation': 'Indiana University', 'homepage': 'https://patshih.luddy.indiana.edu', 'scholar-id': 'Lzw8EnkAAAAJ', 'citations': 2693.0, 'h-index': 25.0}
# 4943
# {'Name': 'Ryan Newton', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~rrnewton/homepage.html', 'scholar-id': 'Bp6dm-oAAAAJ', 'citations': 3677.0, 'h-index': 20.0}
# 4944
# {'Name': 'Amr Sabry', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~sabry', 'scholar-id': 'dYGSG4EAAAAJ', 'citations': 3610.0, 'h-index': 28.0}
# 4945
# {'Name': 'Selma Sabanovic', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=288', 'scholar-id': 'P5pnLAcAAAAJ', 'citations': 3748.0, 'h-index': 31.0}
# 4946
# {'Name': 'Judy Qiu', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~xqiu', 'scholar-id': '0w0Dy34AAAAJ', 'citations': 4432.0, 'h-index': 28.0}
# 4947
# {'Name': 'Yong-Yeol Ahn', 'affiliation': 'Indiana University', 'homepage': 'http://yongyeol.com', 'scholar-id': 'US7OSNgAAAAJ', 'citations': 13215.0, 'h-index': 38.0}
# 4948
# {'Name': 'Jeremy G. Siek', 'affiliation': 'Indiana University', 'homepage': 'http://wphomes.soic.indiana.edu/jsiek', 'scholar-id': 'Vuso8H8AAAAJ', 'citations': 5749.0, 'h-index': 35.0}
# 4949
# {'Name': 'Ron Day', 'affiliation': 'Indiana University', 'homepage': 'https://info.sice.indiana.edu/~roday', 'scholar-id': 'hJsSfQkAAAAJ', 'citations': 2273.0, 'h-index': 18.0}
# 4950
# {'Name': 'Devan Ray Donaldson', 'affiliation': 'Indiana University', 'homepage': 'https://devanraydonaldson.com', 'scholar-id': '0YlLEiIAAAAJ', 'citations': 168.0, 'h-index': 7.0}
# 4951
# {'Name': 'Christopher Raphael', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=279', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4952
# {'Name': 'John A. Walsh', 'affiliation': 'Indiana University', 'homepage': 'https://info.sice.indiana.edu/~jawalsh', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4953
# {'Name': 'Daniel P. Friedman', 'affiliation': 'Indiana University', 'homepage': 'http://www.cs.indiana.edu/~dfried', 'scholar-id': '0yxUr_oAAAAJ', 'citations': 10689.0, 'h-index': 45.0}
# 4954
# {'Name': 'Howard Rosenbaum', 'affiliation': 'Indiana University', 'homepage': 'https://ella.sice.indiana.edu/~hrosenba', 'scholar-id': 'zM9oIWUAAAAJ', 'citations': 2039.0, 'h-index': 20.0}
# 4955
# {'Name': 'Yan Huang', 'affiliation': 'Indiana University', 'homepage': 'http://homes.soic.indiana.edu/yh33', 'scholar-id': 'aKpQjaQAAAAJ', 'citations': 14869.0, 'h-index': 47.0}
# 4956
# {'Name': 'Yijie Wang', 'affiliation': 'Indiana University', 'homepage': 'https://wyjhxq.github.io', 'scholar-id': 'rloap-cAAAAJ', 'citations': 391.0, 'h-index': 9.0}
# 4957
# {'Name': 'Roni Khardon', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/rkhardon', 'scholar-id': 'ymCi4oEAAAAJ', 'citations': 2919.0, 'h-index': 28.0}
# 4958
# {'Name': 'Gregory F. Lewis', 'affiliation': 'Indiana University', 'homepage': 'https://kinseyinstitute.org/about/profiles/glewis.php', 'scholar-id': 'ZQWhMSEAAAAJ', 'citations': 1701, 'h-index': 21}
# 4959
# {'Name': 'Chung-chieh Shan', 'affiliation': 'Indiana University', 'homepage': 'http://homes.soic.indiana.edu/ccshan', 'scholar-id': '3L1yQeQAAAAJ', 'citations': 2972.0, 'h-index': 29.0}
# 4960
# {'Name': 'Christena Nippert-Eng', 'affiliation': 'Indiana University', 'homepage': 'https://luddy.indiana.edu/contact/profile/?profile_id=388', 'scholar-id': 'wnUs1j0AAAAJ', 'citations': 3137, 'h-index': 10}
# 4961
# {'Name': 'Feng Guo', 'affiliation': 'Indiana University', 'homepage': 'https://frankfengguo.weebly.com', 'scholar-id': 'L6lqEq8AAAAJ', 'citations': 4910.0, 'h-index': 37.0}
# 4962
# {'Name': 'Donald S. Williamson', 'affiliation': 'Indiana University', 'homepage': 'http://homes.soic.indiana.edu/williads', 'scholar-id': 'N4gwChgAAAAJ', 'citations': 1901.0, 'h-index': 24.0}
# 4963
# {'Name': 'Qin Zhang', 'affiliation': 'Indiana University', 'homepage': 'http://homes.soic.indiana.edu/qzhangcs', 'scholar-id': '21hVxuUAAAAJ', 'citations': 86494.0, 'h-index': 119.0}
# 4964
# {'Name': 'Geoffrey Brown', 'affiliation': 'Indiana University', 'homepage': 'http://homes.soic.indiana.edu/geobrown', 'scholar-id': 'PrxFp1MAAAAJ', 'citations': 13403.0, 'h-index': 48.0}
# 4965
# {'Name': 'Funda Ergün', 'affiliation': 'Indiana University', 'homepage': 'http://homes.soic.indiana.edu/fergun', 'scholar-id': 'C3Xc9xIAAAAJ', 'citations': 27.0, 'h-index': 3.0}
# 4966
# {'Name': 'Peter M. Todd', 'affiliation': 'Indiana University', 'homepage': 'https://cogs.sitehost.iu.edu/people/profile.php?u=pmtodd', 'scholar-id': 'YOY2MFEAAAAJ', 'citations': 25979.0, 'h-index': 65.0}
# 4967
# {'Name': 'Esfandiar Haghverdi', 'affiliation': 'Indiana University', 'homepage': 'http://homes.soic.indiana.edu/ehaghver', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4968
# {'Name': 'Luyi Xing', 'affiliation': 'Indiana University', 'homepage': 'https://luyixing.weebly.com', 'scholar-id': 'xTjH_GAAAAAJ', 'citations': 872.0, 'h-index': 14.0}
# 4969
# {'Name': 'Stasa Milojevic', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/smilojev', 'scholar-id': 'ElYJ8mUAAAAJ', 'citations': 3431.0, 'h-index': 26.0}
# 4970
# {'Name': 'Filippo Radicchi', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/filiradi', 'scholar-id': 'ErokNqgAAAAJ', 'citations': 13189.0, 'h-index': 42.0}
# 4971
# {'Name': 'Volker Brendel', 'affiliation': 'Indiana University', 'homepage': 'http://brendelgroup.org', 'scholar-id': 'w9oekBcAAAAJ', 'citations': 9592.0, 'h-index': 53.0}
# 4972
# {'Name': 'Noriko Hara', 'affiliation': 'Indiana University', 'homepage': 'http://norikohara.org', 'scholar-id': 'l13_u9wAAAAJ', 'citations': 8637.0, 'h-index': 32.0}
# 4973
# {'Name': 'Ariful Azad', 'affiliation': 'Indiana University', 'homepage': 'https://arifulazad.com', 'scholar-id': '9jK5lfsAAAAJ', 'citations': 1611.0, 'h-index': 17.0}
# 4974
# {'Name': 'Xiaojing Liao', 'affiliation': 'Indiana University', 'homepage': 'http://www.xiaojingliao.com', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4975
# {'Name': 'Chia-Fang Chung', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/cfchung', 'scholar-id': '8GxDKicAAAAJ', 'citations': 871.0, 'h-index': 12.0}
# 4976
# {'Name': 'Mehmet M. Dalkilic', 'affiliation': 'Indiana University', 'homepage': 'http://www.informatics.indiana.edu/dalkilic', 'scholar-id': 'yW-I2CEAAAAJ', 'citations': 135.0, 'h-index': 7.0}
# 4977
# {'Name': 'Lei Jiang', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/jiang60', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4978
# {'Name': 'Lantao Liu', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/lantao', 'scholar-id': 'L5dHk5cAAAAJ', 'citations': 917.0, 'h-index': 17.0}
# 4979
# {'Name': 'Alexander Gumennik', 'affiliation': 'Indiana University', 'homepage': 'https://fames.indiana.edu', 'scholar-id': 'Z-D4ddAAAAAJ', 'citations': 583.0, 'h-index': 13.0}
# 4980
# {'Name': 'Nathan L. Ensmenger', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/nensmeng', 'scholar-id': 'D_cX3_gAAAAJ', 'citations': 1653.0, 'h-index': 15.0}
# 4981
# {'Name': 'R. Clint Whaley', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/rcwhaley', 'scholar-id': 'wgoNS7UAAAAJ', 'citations': 8821, 'h-index': 20}
# 4982
# {'Name': 'Haixu Tang', 'affiliation': 'Indiana University', 'homepage': 'http://www.informatics.indiana.edu/hatang', 'scholar-id': '4Hywr5UAAAAJ', 'citations': 13488.0, 'h-index': 54.0}
# 4983
# {'Name': 'Andrew Lukefahr', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/lukefahr', 'scholar-id': 'tZ4fdX0AAAAJ', 'citations': 814.0, 'h-index': 10.0}
# 4984
# {'Name': 'Eleftherios Garyfallidis', 'affiliation': 'Indiana University', 'homepage': 'https://grg.sice.indiana.edu', 'scholar-id': 'Ln2EyRYAAAAJ', 'citations': 3406.0, 'h-index': 22.0}
# 4985
# {'Name': 'Sandra Kübler', 'affiliation': 'Indiana University', 'homepage': 'https://cl.indiana.edu/~skuebler', 'scholar-id': 'uhM9L5sAAAAJ', 'citations': 5714.0, 'h-index': 27.0}
# 4986
# {'Name': 'Alessandro Flammini', 'affiliation': 'Indiana University', 'homepage': 'http://cnets.indiana.edu/aflammin', 'scholar-id': 'aOzxhScAAAAJ', 'citations': 20970.0, 'h-index': 58.0}
# 4987
# {'Name': 'Daniel Manrique-Vallier', 'affiliation': 'Indiana University', 'homepage': 'http://mypage.iu.edu/~dmanriqu', 'scholar-id': 'ccwLsAsAAAAJ', 'citations': 536.0, 'h-index': 13.0}
# 4988
# {'Name': 'Douglas Hofstadter', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=229', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4989
# {'Name': 'Raj Acharya', 'affiliation': 'Indiana University', 'homepage': 'http://www.cse.psu.edu/~rua1', 'scholar-id': 'v28Y9r8AAAAJ', 'citations': 723.0, 'h-index': 11.0}
# 4990
# {'Name': 'Geoffrey C. Fox', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=203', 'scholar-id': 'dJ-fD-sAAAAJ', 'citations': 41537.0, 'h-index': 85.0}
# 4991
# {'Name': 'Randall Bramley', 'affiliation': 'Indiana University', 'homepage': 'https://www.soic.indiana.edu/all-people/profile.html?profile_id=169', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4992
# {'Name': 'Randall D. Beer', 'affiliation': 'Indiana University', 'homepage': 'http://mypage.iu.edu/~rdbeer', 'scholar-id': 'F_J8QyAAAAAJ', 'citations': 13567.0, 'h-index': 47.0}
# 4993
# {'Name': 'Sam Tobin-Hochstadt', 'affiliation': 'Indiana University', 'homepage': 'http://www.ccs.neu.edu/home/samth', 'scholar-id': 'vMSSQbAAAAAJ', 'citations': 2776.0, 'h-index': 26.0}
# 4994
# {'Name': 'Michael A. McRobbie', 'affiliation': 'Indiana University', 'homepage': 'https://www.sice.indiana.edu/all-people/profile.html?profile_id=254', 'scholar-id': None, 'citations': None, 'h-index': None}
# 4995
# {'Name': 'Matthew W. Hahn', 'affiliation': 'Indiana University', 'homepage': 'https://hahnlab.sitehost.iu.edu', 'scholar-id': 'ShySYTIAAAAJ', 'citations': 26143.0, 'h-index': 77.0}
# 4996
# {'Name': 'Filippo Menczer', 'affiliation': 'Indiana University', 'homepage': 'http://cnets.indiana.edu/fil', 'scholar-id': 'f_kGJwkAAAAJ', 'citations': 30230.0, 'h-index': 77.0}
# 4997
# {'Name': 'Maria Bondessen', 'affiliation': 'Indiana University', 'homepage': 'https://bondessonbolin.wixsite.com/website', 'scholar-id': '9DSdzygAAAAJ', 'citations': 3477.0, 'h-index': 25.0}
# 4998
# {'Name': 'Chen Yu', 'affiliation': 'Indiana University', 'homepage': 'https://psych.indiana.edu/directory/faculty/yu-chen.html', 'scholar-id': 'SA3IoXwAAAAJ', 'citations': 9219.0, 'h-index': 44.0}
# 4999
# {'Name': 'Prateek Sharma', 'affiliation': 'Indiana University', 'homepage': 'http://homes.sice.indiana.edu/prateeks', 'scholar-id': '0vslvCQAAAAJ', 'citations': 1119.0, 'h-index': 15.0}

# %%
professors

# %%
df = pd.DataFrame(professors)
df.to_csv(os.getcwd().replace('code','') +"data/data16.csv", index = False)

# %%
data.iloc[1876]
# Out:
# name                                Chen Ma
# affiliation    City University of Hong Kong
# homepage        https://allenjack.github.io
# scholar_id                     sSy7nvsAAAAJ
# citations                             508.0
# h-index                                10.0
# Name: 1876, dtype: object

# %%
data.loc[data['name']== 'Eatai Roth']
# Out:
#             name         affiliation                  homepage    scholar_id  \
# 5000  Eatai Roth  Indiana University  http://www.eatairoth.com  Wf_rspwAAAAJ
#
#       citations  h-index
# 5000      690.0     12.0

# %%
data.loc[data['affiliation']== 'Chulalongkorn University']
# Out:
#                                  name               affiliation  \
# 1860            Nagul Cooharojananone  Chulalongkorn University
# 1861            Peraphon Sophatsathit  Chulalongkorn University
# 1862  Jaruloj Eamsiri Chongstitvatana  Chulalongkorn University
# 1863                Rajalida Lipikorn  Chulalongkorn University
# 1864            Suphakant Phimoltares  Chulalongkorn University
# 1865       Pattarasinee Bhattarakosol  Chulalongkorn University
# 1866             Chidchanok Lursinsap  Chulalongkorn University
# 1867             Pornsiri Muenchaisri  Chulalongkorn University
# 1868             Krung Sinapiromsaran  Chulalongkorn University
# 1869                 Suchada Siripant  Chulalongkorn University
# 1870                 Dittaya Wanvarie  Chulalongkorn University
# 1871                  Somjai Boonsiri  Chulalongkorn University
# 1872                 Saranya Maneeroj  Chulalongkorn University
# 1873                 Kitiporn Plaimas  Chulalongkorn University
# 1874              Arthorn Luangsodsai  Chulalongkorn University
# 1875            Chatchawit Aporntewan  Chulalongkorn University
#
#                                                homepage     scholar_id  \
# 1860         http://pioneer.netserv.chula.ac.th/~cnagul  NOSCHOLARPAGE
# 1861  https://cop.car.chula.ac.th/%E0%B8%9E%E0%B8%B5...  NOSCHOLARPAGE
# 1862  http://65.54.113.26/Author/3358202/jaruloj-eam...  NOSCHOLARPAGE
# 1863  http://www.math.sc.chula.ac.th/en/profile/raja...  NOSCHOLARPAGE
# 1864     https://cop.car.chula.ac.th/%E0%B8%A8%E0%B8%B8  NOSCHOLARPAGE
# 1865  http://www.math.sc.chula.ac.th/en/profile/patt...   WeFVkqAAAAAJ
# 1866  http://www.math.sc.chula.ac.th/en/profile/chid...  NOSCHOLARPAGE
# 1867  https://www.cp.eng.chula.ac.th/en/about/facult...  NOSCHOLARPAGE
# 1868         http://pioneer.netserv.chula.ac.th/~skrung   Pqic3LgAAAAJ
# 1869       http://pioneer.netserv.chula.ac.th/~ssuchada  NOSCHOLARPAGE
# 1870       http://pioneer.netserv.chula.ac.th/~wdittaya   5lzA94cAAAAJ
# 1871        http://pioneer.netserv.chula.ac.th/~bsomjai  NOSCHOLARPAGE
# 1872  http://www.math.sc.chula.ac.th/en/profile/sara...  NOSCHOLARPAGE
# 1873  http://www.bioinfo.sc.chula.ac.th/people/Kitip...  NOSCHOLARPAGE
# 1874       http://pioneer.netserv.chula.ac.th/~larthorn  NOSCHOLARPAGE
# 1875  http://www.bioinfo.sc.chula.ac.th/people/Chatc...  NOSCHOLARPAGE
#
#       citations  h-index
# 1860        NaN      NaN
# 1861        NaN      NaN
# 1862        NaN      NaN
# 1863        NaN      NaN
# 1864        NaN      NaN
# 1865      880.0     11.0
# 1866        NaN      NaN
# 1867        NaN      NaN
# 1868        NaN      NaN
# 1869        NaN      NaN
# 1870       32.0      4.0
# 1871        NaN      NaN
# 1872        NaN      NaN
# 1873        NaN      NaN
# 1874        NaN      NaN
# 1875        NaN      NaN

# %%
big_data = pd.DataFrame()
for i in range(16):
    temp_data = pd.read_csv(os.getcwd().replace('code','') + f'/data/data{i+1}.csv')
    big_data = pd.concat([big_data,temp_data])
big_data.to_csv(os.getcwd().replace('code','') + '/data/cleaned_prof_data_0_5000.csv', index = False)

# %%
data1 = pd.read_csv(os.getcwd().replace('code','') + "/data/replaced_data_5000_20650.csv")
data2 = pd.read_csv(os.getcwd().replace('code','') + "/data/cleaned_prof_data_0_5000.csv")

# %%
data_3 = pd.concat([data2,data1]).reset_index(drop=True)
data_3.to_csv(os.getcwd().replace('code','') + "/data/cleaned_prof_data_5.csv", index = False)

# %%
data4 = pd.read_csv(os.getcwd().replace('code','') + "/data/replaced_data_8000_20650.csv")

# %%
data4.loc[pd.isna(data['h-index']) & ~pd.isna(data4['h-index'])]
# Out:
# Empty DataFrame
# Columns: [Name, affiliation, homepage, scholar-id, citations, h-index]
# Index: []

# %%
data4.loc[~pd.isna(data['scholar_id']) & pd.isna(data4['scholar-id'])].iloc[456]
# Out:
# Name                                   Franz Puntigam
# affiliation                                   TU Wien
# homepage       http://www.complang.tuwien.ac.at/franz
# scholar-id                                        NaN
# citations                                         NaN
# h-index                                           NaN
# Name: 2592, dtype: object
