# %%
from cmath import isnan
import os
from random import random
import time
from typing import Any
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from csv import writer

# read the data from a file
data = pd.read_csv(os.getcwd().replace('code/old_test_code','') + "/data/cleaned_prof_data_v4.csv")

# initialize web driver for selenium
options = webdriver.ChromeOptions()
options.add_argument('--disable-blink-features=AutomationControlled')
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
driver.implicitly_wait(random() * 10)


def findMaxCitations(web_elements: list):
    indOfMax = 0
    maxVal = 0
    for i in range(len(web_elements)):
        val = int(web_elements[i].text.split(" - ")[2].split(" ")[2])
        if val > maxVal:
            maxVal = val
            indOfMax = i
        else:
            continue
    return web_elements[indOfMax]


# loop through and find all professors with wrong / no google scholar ID
professors = []
professorExists = True

for i in range(19563, data.shape[0]):

    # initialize values
    scholar_id = data.iat[i, 3],
    citations = data.iat[i, 4],
    h_index = data.iat[i, 5]

    if(data.iat[i, 3] == "NOSCHOLARPAGE" or data.iat[i, 3] == "#NAME?" or isnan(data.iat[i, 4]) or isnan(data.iat[i, 5])):
        print("Name: " + data.iat[i, 0] + " | " + "University: " +
              data.iat[i, 1] + " | " + "id: " + data.iat[i, 3])

        # launch URL
        driver.get("https://scholar.google.com")

        # identify search box
        box = driver.find_element(By.NAME, "q")

        # enter search text
        box.send_keys(data.iat[i, 0] + " " + data.iat[i, 1])

        # make search
        box.send_keys(Keys.ENTER)

        # in the case that the author pops up as a recommended option
        try:
            link = driver.find_element(
                By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]/h4/a")
            link.click()
            time.sleep(random() * 3)
            
        except:
            try:
                # in the case there are multiple options in the recommended table
                list_of_elements = driver.find_element(
                    By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]").find_elements(By.TAG_NAME, "div")
                print("case 2 was executed")
                max_element = findMaxCitations(list_of_elements)
                max_element.find_element(By.TAG_NAME, "a").click()
                time.sleep(random() * 5)
            except:
                # otherwise loop through all the divs and find the correct professor
                elements_list = driver.find_element(
                    By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]").find_element(By.CLASS_NAME, "gs_a").find_elements(By.TAG_NAME, "a")
                print(elements_list)
                if elements_list: 
                    for element in elements_list:  # looping through the number of professors in the link
                        try:
                            element.find_element(By.TAG_NAME, "b")
                            element.click()
                            professorExists = True
                            break
                        except NoSuchElementException:
                            professorExists = False
                            continue  # in the case that the element is not found
                    # give time for html / css / js to load
                    time.sleep(random() * 5)
                else: 
                    professorExists = False 

        # retrieve citation, h-index, and scholar_id for that prof
        if professorExists:
            scholar_id = driver.current_url.split("=")[1].split("&")[0]
            citation = driver.find_element(
                By.XPATH, "//*[@id='gsc_rsb_st']/tbody/tr[1]/td[2]").text
            h_index = driver.find_element(
                By.XPATH, "//*[@id='gsc_rsb_st']/tbody/tr[2]/td[2]").text
            time.sleep(random() * 5)
        else:
            scholar_id = None
            citation = None
            h_index = None
        print("scholar_id: " + str(scholar_id) + " h-index: " +
              str(h_index) + " citations: " + str(citation))
        professors.append({
            "Name": data.iat[i, 0],
            "affiliation": data.iat[i, 1],
            "homepage": data.iat[i, 2],
            "scholar-id": scholar_id,
            "citations": citation,
            "h-index": h_index
        })
    else:
        continue


print(len(professors))
df = pd.DataFrame(professors)
df.to_csv("cleaned_prof_data_v5_39.csv")
# Out:
# [WDM] - ====== WebDriver manager ======
# 2022-07-22 19:56:51,887 INFO ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# 2022-07-22 19:56:51,991 INFO Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# 2022-07-22 19:56:51,993 INFO Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/kevins/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# 2022-07-22 19:56:52,093 INFO Driver [/Users/kevins/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_1722/912731158.py:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# Name: Thierry Fournel | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="f4be3f23-0fe1-4d87-a6d1-9bd5bdf31db2")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="7ab07a0e-b63d-433f-88f3-571531f2dc6f")>]
# scholar_id: c31Sf20AAAAJ h-index: 16 citations: 1213
# Name: Alain Trémeau | University: Université Jean Monnet | id: NOSCHOLARPAGE
# scholar_id: XUE41swAAAAJ h-index: 25 citations: 3110
# Name: Hubert Konik | University: Université Jean Monnet | id: NOSCHOLARPAGE
# scholar_id: XywJFH8AAAAJ h-index: 16 citations: 950
# Name: Eric Dinet | University: Université Jean Monnet | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Baptiste Jeudy | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="bd7f42d8-f0e9-4876-bf53-44e2b50f61b4")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="d287b206-ce3e-4fa5-8d23-8bca7c8689a2")>]
# scholar_id: None h-index: None citations: None
# Name: Thierry Lépine | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="dc2ea1c8-571c-466d-bfc1-e99306d3ce54")>]
# scholar_id: NxfMgRgAAAAJ h-index: 11 citations: 979
# Name: Anne-Claire Legrand | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="d02312f1-c649-491c-91a9-a4601a2ecae4")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="51bc7565-981f-41b4-94e4-df77bfded48d")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="30d751c6-173c-4188-92fe-f11fba16e211")>]
# scholar_id: qtlHiRYAAAAJ h-index: 7 citations: 159
# Name: Philippe Ezequel | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="45b676c5-a8f5-412b-8a99-8dd85b6388cc")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="6b0e4e27-4dfb-4861-a587-f7397915ab77")>]
# scholar_id: None h-index: None citations: None
# Name: Virginie Fresse | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="00a68a2d-bf9e-4b1f-a862-8d44bcdb3804")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="5ffa49fe-237c-4ef1-8e02-b1af1a763028")>]
# scholar_id: None h-index: None citations: None
# Name: Julien Subercaze | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="e0567248-fda9-4395-8a27-fcc1adcb4311")>]
# scholar_id: None h-index: None citations: None
# Name: Fabrice Muhlenbach | University: Université Jean Monnet | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="2ea248cf-018f-41cd-a291-c3986d056787")>]
# scholar_id: None h-index: None citations: None
# Name: Ronald Beaubrun | University: Université Laval | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name: Richard Khoury | University: Université Laval | id: PgyHf0oAAAAJ
# scholar_id: None h-index: None citations: None
# Name: Dany Dubé | University: Université Laval | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="9476ca90-e9f0-4ebf-af72-fbbd7c39c596")>]
# scholar_id: None h-index: None citations: None
# Name: Béchir Ktari | University: Université Laval | id: NOSCHOLARPAGE
# []
# scholar_id: None h-index: None citations: None
# Name:
>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="3a84a0bf-6e7b-4f3a-869e-e01d765fa386")>]
# scholar_id: None h-index: None citations: None
# Name: Baogang Wei | University: Zhejiang University | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="53dd23e9-4b2a-4124-aa3d-a15f2f565aaf")>]
# scholar_id: None h-index: None citations: None
# Name: Hujun Bao | University: Zhejiang University | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Yubo Tao | University: Zhejiang University | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="c315d549-2423-403c-bfe5-8ced002b412c")>]
# scholar_id: None h-index: None citations: None
# Name: Youyi Zheng | University: Zhejiang University | id: 7gA-o6gAAAAJ
# scholar_id: None h-index: None citations: None
# Name: Yongwang Zhao | University: Zhejiang University | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Ke Chen | University: Zhejiang University | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="5998992a-0782-49a7-862b-8cd13d1432d4")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="fb29e4ac-59cd-4cfe-92ad-e0a1e9d834fc")>]
# scholar_id: 0Zv2m-cAAAAJ h-index: 15 citations: 838
# Name: Hongzhi Wu | University: Zhejiang University | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="18abbee3-3c6d-40b5-be40-bb337e162b65")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="4a139e5b-f21b-4a13-adf6-8d42cdd4f668")>]
# scholar_id: None h-index: None citations: None
# Name: Lu Chen | University: Zhejiang University | id: gLOpEaIAAAAJ
# []
# scholar_id: None h-index: None citations: None
# Name: Yang Yang | University: Zhejiang University | id: NOSCHOLARPAGE
# scholar_id: None h-index: None citations: None
# Name: Jian-Ling Sun | University: Zhejiang University | id: NOSCHOLARPAGE
# [<selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="0b21caa1-0a86-47ea-a1c3-4e90efa860dc")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="1fe7c094-9b11-48bf-a191-1d0163c2b94d")>, <selenium.webdriver.remote.webelement.WebElement (session="ce715d074de0d47294bdaa1c2113e359", element="b9edcab7-70e1-4188-a77c-b0c0df3bbca6")>]
# scholar_id: None h-index: None citations: None
# Name: Yasar Safkan | University: Özyeğin University | id: NOSCHOLARPAGE
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [56], in <cell line: 41>()
#      65 try:
# ---> 66     link = driver.find_element(
#      67         By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]/h4/a")
#      68     link.click()
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]/h4/a"}
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# 0   chromedriver                        0x000000010d32eef9 chromedriver + 4480761
# 1   chromedriver                        0x000000010d2ba5d3 chromedriver + 4003283
# 2   chromedriver                        0x000000010cf4d338 chromedriver + 410424
# 3   chromedriver                        0x000000010cf835bd chromedriver + 632253
# 4   chromedriver                        0x000000010cf83841 chromedriver + 632897
# 5   chromedriver                        0x000000010cfb57d4 chromedriver + 837588
# 6   chromedriver                        0x000000010cfa0a8d chromedriver + 752269
# 7   chromedriver                        0x000000010cfb34f1 chromedriver + 828657
# 8   chromedriver                        0x000000010cfa0953 chromedriver + 751955
# 9   chromedriver                        0x000000010cf76cd5 chromedriver + 580821
# 10  chromedriver                        0x000000010cf77d25 chromedriver + 584997
# 11  chromedriver                        0x000000010d30002d chromedriver + 4288557
# 12  chromedriver                        0x000000010d3051b3 chromedriver + 4309427
# 13  chromedriver                        0x000000010d30a23f chromedriver + 4330047
# 14  chromedriver                        0x000000010d305dfa chromedriver + 4312570
# 15  chromedriver                        0x000000010d2defef chromedriver + 4153327
# 16  chromedriver                        0x000000010d31fd78 chromedriver + 4418936
# 17  chromedriver                        0x000000010d31feff chromedriver + 4419327
# 18  chromedriver                        0x000000010d336ab5 chromedriver + 4512437
# 19  libsystem_pthread.dylib             0x00007ff81b1cb4e1 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff81b1c6f6b thread_start + 15
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# Input In [56], in <cell line: 41>()
#      72 try:
#      73     # in the case there are multiple options in the recommended table
# ---> 74     list_of_elements = driver.find_element(
#      75         By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]").find_elements(By.TAG_NAME, "div")
#      76     print("case 2 was executed")
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id='gs_res_ccl_mid']/div[1]/table/tbody/tr/td[2]"}
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# 0   chromedriver                        0x000000010d32eef9 chromedriver + 4480761
# 1   chromedriver                        0x000000010d2ba5d3 chromedriver + 4003283
# 2   chromedriver                        0x000000010cf4d338 chromedriver + 410424
# 3   chromedriver                        0x000000010cf835bd chromedriver + 632253
# 4   chromedriver                        0x000000010cf83841 chromedriver + 632897
# 5   chromedriver                        0x000000010cfb57d4 chromedriver + 837588
# 6   chromedriver                        0x000000010cfa0a8d chromedriver + 752269
# 7   chromedriver                        0x000000010cfb34f1 chromedriver + 828657
# 8   chromedriver                        0x000000010cfa0953 chromedriver + 751955
# 9   chromedriver                        0x000000010cf76cd5 chromedriver + 580821
# 10  chromedriver                        0x000000010cf77d25 chromedriver + 584997
# 11  chromedriver                        0x000000010d30002d chromedriver + 4288557
# 12  chromedriver                        0x000000010d3051b3 chromedriver + 4309427
# 13  chromedriver                        0x000000010d30a23f chromedriver + 4330047
# 14  chromedriver                        0x000000010d305dfa chromedriver + 4312570
# 15  chromedriver                        0x000000010d2defef chromedriver + 4153327
# 16  chromedriver                        0x000000010d31fd78 chromedriver + 4418936
# 17  chromedriver                        0x000000010d31feff chromedriver + 4419327
# 18  chromedriver                        0x000000010d336ab5 chromedriver + 4512437
# 19  libsystem_pthread.dylib             0x00007ff81b1cb4e1 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff81b1c6f6b thread_start + 15
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# Input In [56], in <cell line: 41>()
#      79     time.sleep(random() * 5)
#      80 except:
#      81     # otherwise loop through all the divs and find the correct professor
# ---> 82     elements_list = driver.find_element(
#      83         By.XPATH, "//*[@id='gs_res_ccl_mid']/div[1]").find_element(By.CLASS_NAME, "gs_a").find_elements(By.TAG_NAME, "a")
#      84     print(elements_list)
#      85     if elements_list:
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1248     by = By.CSS_SELECTOR
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id='gs_res_ccl_mid']/div[1]"}
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# 0   chromedriver                        0x000000010d32eef9 chromedriver + 4480761
# 1   chromedriver                        0x000000010d2ba5d3 chromedriver + 4003283
# 2   chromedriver                        0x000000010cf4d338 chromedriver + 410424
# 3   chromedriver                        0x000000010cf835bd chromedriver + 632253
# 4   chromedriver                        0x000000010cf83841 chromedriver + 632897
# 5   chromedriver                        0x000000010cfb57d4 chromedriver + 837588
# 6   chromedriver                        0x000000010cfa0a8d chromedriver + 752269
# 7   chromedriver                        0x000000010cfb34f1 chromedriver + 828657
# 8   chromedriver                        0x000000010cfa0953 chromedriver + 751955
# 9   chromedriver                        0x000000010cf76cd5 chromedriver + 580821
# 10  chromedriver                        0x000000010cf77d25 chromedriver + 584997
# 11  chromedriver                        0x000000010d30002d chromedriver + 4288557
# 12  chromedriver                        0x000000010d3051b3 chromedriver + 4309427
# 13  chromedriver                        0x000000010d30a23f chromedriver + 4330047
# 14  chromedriver                        0x000000010d305dfa chromedriver + 4312570
# 15  chromedriver                        0x000000010d2defef chromedriver + 4153327
# 16  chromedriver                        0x000000010d31fd78 chromedriver + 4418936
# 17  chromedriver                        0x000000010d31feff chromedriver + 4419327
# 18  chromedriver                        0x000000010d336ab5 chromedriver + 4512437
# 19  libsystem_pthread.dylib             0x00007ff81b1cb4e1 _pthread_start + 125
# 20  libsystem_pthread.dylib             0x00007ff81b1c6f6b thread_start + 15

# %%
professors
# Out:
# [{'Name': 'Fabrizio Baiardi',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~tonelli/baiardi',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Francesco Romani',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~romani',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Fabrizio Luccio',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~luccio',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Massimo Pappalardo',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://pages.di.unipi.it/mpappalardo',
#   'scholar-id': 'GWrrWeEAAAAJ',
#   'citations': '1273',
#   'h-index': '18'},
#  {'Name': 'Francesca Levi',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~levifran',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andrea Maggiolo Schettini',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~maggiolo',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Carlo Montangero',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~monta',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Linda Pagli',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~pagli',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Paolo Mancarella',
#   'affiliation': 'University of Pisa',
#   'homepage': 'http://www.di.unipi.it/~paolo',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Donald M. Chiarulli',
#   'affiliation': 'University of Pittsburgh',
#   'homepage': 'https://people.cs.pitt.edu/~don',
#   'scholar-id': 'mpiF9EUAAAAJ',
#   'citations': '2309',
#   'h-index': '27'},
#  {'Name': 'Bruce R. Childers',
#   'affiliation': 'University of Pittsburgh',
#   'homepage': 'https://www.cs.pitt.edu/~childers',
#   'scholar-id': '017pCpkAAAAJ',
#   'citations': '14679',
#   'h-index': '62'},
#  {'Name': 'James Currier',
#   'affiliation': 'University of Pittsburgh',
#   'homepage': 'http://www.sci.pitt.edu/faculty-and-research/faculty-directory/james-d-kip-currier',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Erin Walker',
#   'affiliation': 'University of Pittsburgh',
#   'homepage': 'https://cs.pitt.edu/faculty/tenure-stream/erin-walker',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Shi-Kuo Chang',
#   'affiliation': 'University of Pittsburgh',
#   'homepage': 'https://cs.pitt.edu/~chang',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Kayla Booth',
#   'affiliation': 'University of Pittsburgh',
#   'homepage': 'http://www.sci.pitt.edu/faculty-and-research/faculty-directory/kayla-booth',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Mary K. Biagini',
#   'affiliation': 'University of Pittsburgh',
#   'homepage': 'http://www.sci.pitt.edu/faculty-and-research/faculty-directory/mary-k-biagini',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bettina Schnor',
#   'affiliation': 'University of Potsdam',
#   'homepage': 'https://www.cs.uni-potsdam.de/~schnor',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andreas Schwill',
#   'affiliation': 'University of Potsdam',
#   'homepage': 'http://ddi.cs.uni-potsdam.de/Personen/schwill',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ulrike Lucke',
#   'affiliation': 'University of Potsdam',
#   'homepage': 'https://www.uni-potsdam.de/de/multimedia/team/profdr-inghabilulrikelucke',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Benno Stabernack',
#   'affiliation': 'University of Potsdam',
#   'homepage': 'https://www.uni-potsdam.de/de/aess/mitarbeiter/mitarbeiter',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Norbert Gronau',
#   'affiliation': 'University of Potsdam',
#   'homepage': 'https://lswi.de/lehrstuhl/personen/lehrstuhlinhaber/univ-prof-dr-ing-habil-norbert-gronau',
#   'scholar-id': 'kQ2QCSYAAAAJ',
#   'citations': '4026',
#   'h-index': '29'},
#  {'Name': 'Graeme Smith',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://staff.itee.uq.edu.au/smith',
#   'scholar-id': 'JRxfQowAAAAJ',
#   'citations': '3802',
#   'h-index': '24'},
#  {'Name': 'Feng Liu',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://researchers.uq.edu.au/researcher/951',
#   'scholar-id': 'cpUKNrMAAAAJ',
#   'citations': '4127',
#   'h-index': '33'},
#  {'Name': 'Stephen James Wilson',
#   'affiliation': 'University of Queensland',
#   'homepage': 'https://researchers.uq.edu.au/researcher/271',
#   'scholar-id': 'LbH_GdYAAAAJ',
#   'citations': '4691',
#   'h-index': '37'},
#  {'Name': 'Alexander Pudmenzky',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://researchers.uq.edu.au/researcher/804',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Lorna MacDonald',
#   'affiliation': 'University of Queensland',
#   'homepage': 'https://researchers.uq.edu.au/researcher/1071',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Garry Marling',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://www.smi.uq.edu.au/user/203',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ryan K. L. Ko',
#   'affiliation': 'University of Queensland',
#   'homepage': 'https://researchers.uq.edu.au/researcher/23784',
#   'scholar-id': 'kyTPC7cAAAAJ',
#   'citations': '3186',
#   'h-index': '23'},
#  {'Name': 'Udantha Ranjith Abeyratne',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://www.itee.uq.edu.au/bme/abeyratne',
#   'scholar-id': 'mccLWM4AAAAJ',
#   'citations': '2775',
#   'h-index': '29'},
#  {'Name': 'Saeid Mehrkanoon',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://researchers.uq.edu.au/researcher/14135',
#   'scholar-id': 'UMbNsJMAAAAJ',
#   'citations': '377',
#   'h-index': '11'},
#  {'Name': "Peter O'Shea",
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://researchers.uq.edu.au/researcher/11892',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Paul E. I. Pounds',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://www.itee.uq.edu.au/bme/pounds',
#   'scholar-id': 'b3cGSpgAAAAJ',
#   'citations': '3410',
#   'h-index': '25'},
#  {'Name': 'Shazia W. Sadiq',
#   'affiliation': 'University of Queensland',
#   'homepage': 'http://researchers.uq.edu.au/researcher/792',
#   'scholar-id': '1Jo0EmIAAAAJ',
#   'citations': '9094',
#   'h-index': '47'},
#  {'Name': 'Bo-Ting Yang',
#   'affiliation': 'University of Regina',
#   'homepage': 'http://www.cs.uregina.ca/People/Profiles/BotingYang.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Malek Mouhoub',
#   'affiliation': 'University of Regina',
#   'homepage': 'http://www.cs.uregina.ca/People/Profiles/MalekMouhoub.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Samira Sadaoui',
#   'affiliation': 'University of Regina',
#   'homepage': 'http://www.cs.uregina.ca/People/Profiles/SamiraSadaouiMouhoub.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Lisa Fan',
#   'affiliation': 'University of Regina',
#   'homepage': 'http://www.cs.uregina.ca/People/Profiles/LisaFan.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Robert J. Hilderman',
#   'affiliation': 'University of Regina',
#   'homepage': 'http://www.cs.uregina.ca/People/Profiles/RobertHilderman.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Xue Dong Yang',
#   'affiliation': 'University of Regina',
#   'homepage': 'http://www.cs.uregina.ca/People/Profiles/XueDongYang.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Daniel Stefankovic',
#   'affiliation': 'University of Rochester',
#   'homepage': 'https://www.cs.rochester.edu/~stefanko',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Kai Shen',
#   'affiliation': 'University of Rochester',
#   'homepage': 'https://www.cs.rochester.edu/u/kshen',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Lenhart K. Schubert',
#   'affiliation': 'University of Rochester',
#   'homepage': 'https://www.cs.rochester.edu/~schubert',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Daniel Gildea',
#   'affiliation': 'University of Rochester',
#   'homepage': 'https://www.cs.rochester.edu/u/gildea',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Randal C. Nelson',
#   'affiliation': 'University of Rochester',
#   'homepage': 'https://www.cs.rochester.edu/~nelson',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Joel I. Seiferas',
#   'affiliation': 'University of Rochester',
#   'homepage': 'https://www.cs.rochester.edu/~joel',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andreas Heuer',
#   'affiliation': 'University of Rostock',
#   'homepage': 'https://dbis.informatik.uni-rostock.de/mitarbeiter/heuer/andreas-heuer',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bodo Urban',
#   'affiliation': 'University of Rostock',
#   'homepage': 'https://www.igd.fraunhofer.de/institut/ueber-uns/alumni/bodo-urban',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Michael Fellmann',
#   'affiliation': 'University of Rostock',
#   'homepage': 'https://www.wibis.uni-rostock.de/team',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Giancarlo Nota',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/giancarlonota/en/index',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Gianluca De Marco',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/gianlucademarco/index',
#   'scholar-id': 'Eg0ZuKUAAAAJ',
#   'citations': '703',
#   'h-index': '14'},
#  {'Name': 'Maurizio Tucci',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/mauriziotucci/index',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Vincenzo Auletta',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/vincenzoauletta/en/index',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Giuliana Vitiello',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/giulianavitiello/english/index',
#   'scholar-id': 'ZQITnvAAAAAJ',
#   'citations': '1936',
#   'h-index': '25'},
#  {'Name': 'Riccardo Distasi',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/riccardodistasi/index',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Roberto Tagliaferri',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/robertotagliaferri/en/index',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Genny Tortora',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/genoveffatortora/index',
#   'scholar-id': '7PX-djYAAAAJ',
#   'citations': '7333',
#   'h-index': '39'},
#  {'Name': 'Monica Sebillo',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/monicamariasebillo/index',
#   'scholar-id': 'xzUw4jQAAAAJ',
#   'citations': '1124',
#   'h-index': '18'},
#  {'Name': 'Francesco Tortorella',
#   'affiliation': 'University of Salerno',
#   'homepage': 'https://docenti.unisa.it/041789/home',
#   'scholar-id': 'ftFwRzMAAAAJ',
#   'citations': '1974',
#   'h-index': '24'},
#  {'Name': 'Raffaele Pizzolante',
#   'affiliation': 'University of Salerno',
#   'homepage': 'https://docenti.unisa.it/025505/home',
#   'scholar-id': 'zUUav3AAAAAJ',
#   'citations': '628',
#   'h-index': '15'},
#  {'Name': 'Angelo Marcelli',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://docenti.unisa.it/003780/home',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Rosalba Zizza',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.di.unisa.it/professori/zizza',
#   'scholar-id': 'wv21l2IAAAAJ',
#   'citations': '365',
#   'h-index': '13'},
#  {'Name': 'Marcella Anselmo',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.di.unisa.it/professori/anselmo',
#   'scholar-id': 'YwQTOUMAAAAJ',
#   'citations': '593',
#   'h-index': '15'},
#  {'Name': 'Alberto Negro',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://www.unisa.it/docenti/albertonegro/en/index',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Filomena Ferrucci',
#   'affiliation': 'University of Salerno',
#   'homepage': 'http://salerno.academia.edu/FilomenaFerrucci',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Martin Held',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'https://www.cosy.sbg.ac.at/~held/held.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Nikolaus Augsten',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'https://dbresearch.uni-salzburg.at/people/augsten',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Wolfgang Pree',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'http://www.softwareresearch.net/home',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Rade Kutil',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'https://www.cosy.sbg.ac.at/~rkutil',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Helmut A. Mayer',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'https://www.cosy.sbg.ac.at/~helmut/helmut.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Stefan Resmerita',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'http://cs.uni-salzburg.at/~stefan.resmerita',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Elmar Eder',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'https://www.cosy.sbg.ac.at/~eder/eder.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andreas Naderlinger',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'http://www.cs.uni-salzburg.at/~andreas.naderlinger',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andreas Uhl',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'https://www.cosy.sbg.ac.at/~uhl',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Helge Hagenauer',
#   'affiliation': 'University of Salzburg',
#   'homepage': 'https://www.cosy.sbg.ac.at/~hagenau',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Aniello Cimitile',
#   'affiliation': 'University of Sannio',
#   'homepage': 'https://www.ding.unisannio.it/persone/docenti/cimitile',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Matthew Links',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'https://agbio.usask.ca/faculty-and-staff/people-pages/matthew-links.php',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Christopher Dutchyn',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'https://www.cs.usask.ca/faculty/cjd032',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Chanchal Roy',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'https://www.cs.usask.ca/~croy',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Michael Horsch',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'http://artsandscience.usask.ca/profile/MHorsch',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ian McQuillan',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'https://www.cs.usask.ca/faculty/mcquillan',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Kevin Stanley',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'http://www.cs.usask.ca/faculty/stanley/kstanley',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Nadeem Jamali',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'http://agents.usask.ca/Agents_Lab/Nadeem_Jamali.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Tony Kusalik',
#   'affiliation': 'University of Saskatchewan',
#   'homepage': 'http://artsandscience.usask.ca/profile/AKusalik',
#   'scholar-id': '17NLe_IAAAAJ',
#   'citations': '2803',
#   'h-index': '29'},
#  {'Name': 'Anton Ragni',
#   'affiliation': 'University of Sheffield',
#   'homepage': 'https://www.sheffield.ac.uk/dcs/people/academic/anton-ragni',
#   'scholar-id': 'bK8wK0EAAAAJ',
#   'citations': '1143',
#   'h-index': '21'},
#  {'Name': 'Loïc Barrault',
#   'affiliation': 'University of Sheffield',
#   'homepage': 'https://www.sheffield.ac.uk/dcs/people/academic/loic-barrault',
#   'scholar-id': 'S6Xj1BYAAAAJ',
#   'citations': '5918',
#   'h-index': '23'},
#  {'Name': 'Jon Barker',
#   'affiliation': 'University of Sheffield',
#   'homepage': 'https://www.sheffield.ac.uk/dcs/people/academic/jon-barker',
#   'scholar-id': '-wmRVxoAAAAJ',
#   'citations': '6048',
#   'h-index': '33'},
#  {'Name': 'Markus Lohrey',
#   'affiliation': 'University of Siegen',
#   'homepage': 'https://www.eti.uni-siegen.de/ti/mitarbeiter/lohrey',
#   'scholar-id': '6EjzYkcAAAAJ',
#   'citations': '2778',
#   'h-index': '29'},
#  {'Name': 'Klaus-Dieter Kuhnert',
#   'affiliation': 'University of Siegen',
#   'homepage': 'https://fokos.de/personal/prof-dr-ing-klaus-dieter-kuhnert',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Michael G. Wahl',
#   'affiliation': 'University of Siegen',
#   'homepage': 'https://www.eti.uni-siegen.de/dis/mitarbeiter/wahl.html?lang=de',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Roland Wismüller',
#   'affiliation': 'University of Siegen',
#   'homepage': 'https://www.bs.informatik.uni-siegen.de/mitarbeiter/wismueller/index_html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Udo Kelter',
#   'affiliation': 'University of Siegen',
#   'homepage': 'http://pi.informatik.uni-siegen.de/kelter',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Madjid Fathi',
#   'affiliation': 'University of Siegen',
#   'homepage': 'https://www.eti.uni-siegen.de/ws/mitarbeiter/m_fathi/index.html?lang=de',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Caroline M. Eastman',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'https://cse.sc.edu/~eastman',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Matt E. Thatcher',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'https://www.sc.edu/study/colleges_schools/engineering_and_computing/faculty-staff/mattthatcher.php',
#   'scholar-id': '3Rz6pOIAAAAJ',
#   'citations': '7244',
#   'h-index': '31'},
#  {'Name': 'Manton M. Matthews',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'https://cse.sc.edu/~matthews',
#   'scholar-id': 'VRF_3FsAAAAJ',
#   'citations': '1272',
#   'h-index': '12'},
#  {'Name': 'Vignesh Narayanan',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'https://vigsnar.github.io',
#   'scholar-id': 'rirGB10AAAAJ',
#   'citations': '360',
#   'h-index': '10'},
#  {'Name': 'Qiang Zeng',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'https://cse.sc.edu/~zeng1',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Marco G. Valtorta',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'http://www.cse.sc.edu/~mgv',
#   'scholar-id': 'l53UPjoAAAAJ',
#   'citations': '1786',
#   'h-index': '21'},
#  {'Name': 'John R. Rose',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'http://www.cse.sc.edu/~rose',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Stephen A. Fenner',
#   'affiliation': 'University of South Carolina',
#   'homepage': 'http://www.cse.sc.edu/~fenner',
#   'scholar-id': 'VGn3SEoAAAAJ',
#   'citations': '1254',
#   'h-index': '18'},
#  {'Name': 'William Armitage',
#   'affiliation': 'University of South Florida',
#   'homepage': 'http://www.usf.edu/engineering/cse/people',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Denis A. Nicole',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/dan1',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Yvonne Margaret Howard',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/ymhoward',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bing Chu',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/bc1d11',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andrew Sogokon',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/as1g19#research',
#   'scholar-id': '-WBF91wAAAAJ',
#   'citations': '194',
#   'h-index': '8'},
#  {'Name': 'Neil M. White',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/neilw',
#   'scholar-id': '-KqNHGQAAAAJ',
#   'citations': '14741',
#   'h-index': '50'},
#  {'Name': 'Eric Rogers',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/er',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'R. A. Bodnar',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/rab1e14',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Timothy J. Norman',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/tjn1f15',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ken S. Thomas',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/kst',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Klaus-Peter Zauner',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/kpz',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Julian Rathke',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/jr1a06',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andrew M. Gravell',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/gravell#research',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Markus Brede',
#   'affiliation': 'University of Southampton',
#   'homepage': 'https://www.ecs.soton.ac.uk/people/mb1a10#research',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Aiichiro Nakano',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://physics.usc.edu/Faculty/Nakano',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Melvin A. Breuer',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://ee.usc.edu/faculty_staff/faculty_directory/breuer.htm',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ulrich Neumann',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://graphics.usc.edu/cgit/un.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ellis Horowitz',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://www.ellishorowitz.com',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Michael S. Waterman',
#   'affiliation': 'University of Southern California',
#   'homepage': 'https://dornsife.usc.edu/labs/msw',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Dennis McLeod',
#   'affiliation': 'University of Southern California',
#   'homepage': 'https://viterbi.usc.edu/directory/faculty/McLeod/Dennis',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Rajiv K. Kalia',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://physics.usc.edu/Faculty/Kalia',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Fei Sha',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://www-bcf.usc.edu/~feisha',
#   'scholar-id': 'HDHOS0QAAAAJ',
#   'citations': '16570',
#   'h-index': '50'},
#  {'Name': 'Yan Liu',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://www-bcf.usc.edu/~liu32',
#   'scholar-id': 'UUKLPMYAAAAJ',
#   'citations': '14694',
#   'h-index': '55'},
#  {'Name': 'Ming-Deh A. Huang',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://www-bcf.usc.edu/~mdhuang',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Kai Hwang',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://gridsec.usc.edu/Hwang.html',
#   'scholar-id': 'igFuAncAAAAJ',
#   'citations': '23071',
#   'h-index': '64'},
#  {'Name': 'Len Adleman',
#   'affiliation': 'University of Southern California',
#   'homepage': 'https://www.usc.edu/dept/molecular-science/fm-adleman.htm',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Shang-Hua Teng',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://www-bcf.usc.edu/~shanghua',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Xianghong Jasmine Zhou',
#   'affiliation': 'University of Southern California',
#   'homepage': 'http://zhoulab.usc.edu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Dia Ali',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'https://www.usm.edu/computing/faculty/dia-ali',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bikramjit Banerjee',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'https://www.usm.edu/computing/faculty/bikramjit-banerjee',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Chaoyang Zhang',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'http://orca.st.usm.edu/~zhang',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Nan Wang',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'http://orca.st.usm.edu/~nwang',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Wonryull Koh',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'https://www.usm.edu/computing/faculty/wonryull-koh',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Kuo Chen',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'https://www.usm.edu/computing/faculty/kuo-chen',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Beddhu Murali',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'https://www.usm.edu/computing/faculty/beddhu-murali',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Amer Dawoud',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'https://www.usm.edu/computing/faculty/amer-dawoud',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Connie White',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'https://www.usm.edu/computing',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Zheng Wang',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'http://www.cs.miami.edu/home/zwang',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Zhaoxian Zhou',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'http://orca.st.usm.edu/~zzhou',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Jonathan Sun',
#   'affiliation': 'University of Southern Mississippi',
#   'homepage': 'http://www.cs.usm.edu/~jsun',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ian Gent',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'http://ian.gent',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Saleem Bhatti',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://saleem.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Alan Dearle',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://al.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ruth Letham',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://rah11.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'John Thomson',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://jt.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Jonathan Lewis',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://jonl.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Mike Weir',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://mkw.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ishbel Duncan',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://ishbel.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ognjen Arandjelovic',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://oa7.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Dharini Balasubramaniam',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://dharini.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'David Harris-Birtill',
#   'affiliation': 'University of St Andrews',
#   'homepage': 'https://dcchb.host.cs.st-andrews.ac.uk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Erhard Plödereder',
#   'affiliation': 'University of Stuttgart',
#   'homepage': 'http://www.iste.uni-stuttgart.de/ps/team/ploedereder.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Martin Radetzki',
#   'affiliation': 'University of Stuttgart',
#   'homepage': 'https://www.iti.uni-stuttgart.de/en/chairs/embedded-systems/people/martin-radetzki.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Volker Diekert',
#   'affiliation': 'University of Stuttgart',
#   'homepage': 'http://www.fmi.uni-stuttgart.de/ti/personen/Diekert',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Sven Simon',
#   'affiliation': 'University of Stuttgart',
#   'homepage': 'https://www.ipvs.uni-stuttgart.de/abteilungen/pas/abteilung/mitarbeiter/sven.simon?__locale=en',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ralf Küsters',
#   'affiliation': 'University of Stuttgart',
#   'homepage': 'https://sec.informatik.uni-stuttgart.de/people/kuesters',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Dieter Roller',
#   'affiliation': 'University of Stuttgart',
#   'homepage': 'http://www.iris.uni-stuttgart.de/institut/mitarbeiter/roller.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Uwe Reyle',
#   'affiliation': 'University of Stuttgart',
#   'homepage': 'http://www.ims.uni-stuttgart.de/institut/mitarbeiter/uwe',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Chris Thornton',
#   'affiliation': 'University of Sussex',
#   'homepage': 'http://www.sussex.ac.uk/informatics/people/peoplelists/person/2684',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Paul F. Newbury',
#   'affiliation': 'University of Sussex',
#   'homepage': 'http://www.sussex.ac.uk/informatics/people/peoplelists/person/126552',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'David J. Weir',
#   'affiliation': 'University of Sussex',
#   'homepage': 'http://www.sussex.ac.uk/informatics/people/peoplelists/person/2860',
#   'scholar-id': 'DxGZlC4AAAAJ',
#   'citations': '3125',
#   'h-index': '22'},
#  {'Name': 'Ian Mackie',
#   'affiliation': 'University of Sussex',
#   'homepage': 'http://www.sussex.ac.uk/informatics/people/peoplelists/person/212026',
#   'scholar-id': '6B5sAdsAAAAJ',
#   'citations': '1528',
#   'h-index': '20'},
#  {'Name': 'Natalia Beloff',
#   'affiliation': 'University of Sussex',
#   'homepage': 'http://www.sussex.ac.uk/informatics/people/peoplelists/person/109401',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Sharon Wood',
#   'affiliation': 'University of Sussex',
#   'homepage': 'http://www.sussex.ac.uk/informatics/people/peoplelists/person/2974',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bernhard Reus',
#   'affiliation': 'University of Sussex',
#   'homepage': 'http://www.sussex.ac.uk/informatics/people/peoplelists/person/115097',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Fabio Ramos',
#   'affiliation': 'University of Sydney',
#   'homepage': 'http://www-personal.acfr.usyd.edu.au/f.ramos/Fabio_Ramos_Homepage/Home.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'John Stavrakakis',
#   'affiliation': 'University of Sydney',
#   'homepage': 'http://sydney.edu.au/engineering/it/about/people/lecturers.shtml',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Vera Chung',
#   'affiliation': 'University of Sydney',
#   'homepage': 'http://sydney.edu.au/engineering/people/vera.chung.php',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bing Bing Zhou',
#   'affiliation': 'University of Sydney',
#   'homepage': 'http://www.it.usyd.edu.au/~bzho9612',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Na Liu',
#   'affiliation': 'University of Sydney',
#   'homepage': 'https://sydney.edu.au/engineering/people/liu.na.php',
#   'scholar-id': 'PBDco2kAAAAJ',
#   'citations': '461',
#   'h-index': '13'},
#  {'Name': 'József Békési',
#   'affiliation': 'University of Szeged',
#   'homepage': 'http://www.jgypk.hu/~bekesi',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Vambola Leping',
#   'affiliation': 'University of Tartu',
#   'homepage': 'http://www.ut.ee/en/vambola-leping',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Siim Karus',
#   'affiliation': 'University of Tartu',
#   'homepage': 'http://www.ut.ee/en/siim-karus',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Reimo Palm',
#   'affiliation': 'University of Tartu',
#   'homepage': 'http://www.ut.ee/en/reimo-palm',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Helle Hein',
#   'affiliation': 'University of Tartu',
#   'homepage': 'http://www.ut.ee/en/kontakt/arvutiteaduse-instituut',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ahti Peder',
#   'affiliation': 'University of Tartu',
#   'homepage': 'http://www.ut.ee/en/ahti-peder',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Härmel Nestra',
#   'affiliation': 'University of Tartu',
#   'homepage': 'http://www.ut.ee/en/harmel-nestra',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Fabrizio Maria Maggi',
#   'affiliation': 'University of Tartu',
#   'homepage': 'https://www.etis.ee/Portal/Persons/Display/a37d438b-3add-4c4f-8e49-dfacab570f23',
#   'scholar-id': 'Jo9fNKEAAAAJ',
#   'citations': '7708',
#   'h-index': '46'},
#  {'Name': 'Tony He',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/tony.he1',
#   'scholar-id': 'dMMR06sAAAAJ',
#   'citations': '1172',
#   'h-index': '17'},
#  {'Name': 'Jonghyuk Kim',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/jonghyuk.kim',
#   'scholar-id': 'md84WxYAAAAJ',
#   'citations': '2817',
#   'h-index': '23'},
#  {'Name': 'Steve Wozniak',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/stephen.wozniak',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Xun Wang',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/xun.wang-1',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Benjamin Johnston',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/benjamin.johnston',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Barry Jay',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/barry.jay',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Mary-Anne Williams',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/mary-anne.williams',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ling Chen',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/ling.chen',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Jesse Clark',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/jesse.clark',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Sanjiang Li',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/sanjiang.li',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Beinat Paul',
#   'affiliation': 'University of Technology Sydney',
#   'homepage': 'https://www.uts.edu.au/staff/paul.beinat',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Yilu Liu',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://www.eecs.utk.edu/people/faculty/liu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Benjamin J. Blalock',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://web.eecs.utk.edu/~bblalock',
#   'scholar-id': 'K-nxf74AAAAJ',
#   'citations': '6773',
#   'h-index': '41'},
#  {'Name': 'Kai Sun',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://web.eecs.utk.edu/~kaisun',
#   'scholar-id': 'iYCM0GYAAAAJ',
#   'citations': '6086',
#   'h-index': '39'},
#  {'Name': 'Jens Gregor',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://web.eecs.utk.edu/~jgregor',
#   'scholar-id': 'dr5mE48AAAAJ',
#   'citations': '1002',
#   'h-index': '20'},
#  {'Name': 'Amir Sadovnik',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://uvu.eecs.utk.edu',
#   'scholar-id': 'OBuu9_YAAAAJ',
#   'citations': '362',
#   'h-index': '9'},
#  {'Name': 'Brad T. Vander Zanden',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://web.eecs.utk.edu/~bvz',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Seddik M. Djouadi',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'https://www.eecs.utk.edu/people/faculty/mdjouadi',
#   'scholar-id': '2JfQjLMAAAAJ',
#   'citations': '1966',
#   'h-index': '21'},
#  {'Name': 'Héctor Pulgar-Painemal',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'https://www.eecs.utk.edu/people/faculty/hpulgar',
#   'scholar-id': 'aXJa1EcAAAAJ',
#   'citations': '885',
#   'h-index': '16'},
#  {'Name': 'Michael D. Vose',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://www.eecs.utk.edu/people/faculty/mvose1',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Max Schuchard',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'https://web.eecs.utk.edu/~mschucha/index.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Nicole McFarlane',
#   'affiliation': 'University of Tennessee',
#   'homepage': 'http://www.eecs.utk.edu/people/faculty/mcf',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Natalia Villanueva-Rosales',
#   'affiliation': 'University of Texas - El Paso',
#   'homepage': 'https://www.utep.edu/newsfeed/campus/Smart-Cities-Grant-Fosters-International-Collaborations.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Luc Longpré',
#   'affiliation': 'University of Texas - El Paso',
#   'homepage': 'http://faculty.utep.edu/longpre',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ann Q. Gates',
#   'affiliation': 'University of Texas - El Paso',
#   'homepage': 'http://faculty.utep.edu/Default.aspx?alias=faculty.utep.edu/agates',
#   'scholar-id': 'SfdnQ60AAAAJ',
#   'citations': '1740',
#   'h-index': '21'},
#  {'Name': 'Yoonsik Cheon',
#   'affiliation': 'University of Texas - El Paso',
#   'homepage': 'http://www.cs.utep.edu/cheon',
#   'scholar-id': 'lxaj4-sAAAAJ',
#   'citations': '3936',
#   'h-index': '26'},
#  {'Name': 'Martine Ceberio',
#   'affiliation': 'University of Texas - El Paso',
#   'homepage': 'http://utep.academia.edu/MartineCeberio',
#   'scholar-id': 'uI_FmL8AAAAJ',
#   'citations': '829',
#   'h-index': '15'},
#  {'Name': 'Salamah Salamah',
#   'affiliation': 'University of Texas - El Paso',
#   'homepage': 'http://www.cs.utep.edu/isalamah',
#   'scholar-id': 'YnVRhnkAAAAJ',
#   'citations': '258',
#   'h-index': '8'},
#  {'Name': 'Ming Li',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'https://mentis.uta.edu/explore/profile/ming-li',
#   'scholar-id': 'pVqH3WcAAAAJ',
#   'citations': '1439',
#   'h-index': '21'},
#  {'Name': 'Yonghe Liu',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'https://www.uta.edu/profiles/yonghe-liu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Fillia Makedon',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'http://heracleia.uta.edu/~makedon',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Farhad Ahani Kamangar',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'http://ranger.uta.edu/~kamangar',
#   'scholar-id': 'E23Ps_EAAAAJ',
#   'citations': '1320',
#   'h-index': '14'},
#  {'Name': 'Shirin Nilizadeh',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'http://crystal.uta.edu/~shirin',
#   'scholar-id': 'UaSo4BoAAAAJ',
#   'citations': '865',
#   'h-index': '12'},
#  {'Name': 'Ramez A. Elmasri',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'http://ranger.uta.edu/~elmasri',
#   'scholar-id': 'lPtRH2wAAAAJ',
#   'citations': '18307',
#   'h-index': '42'},
#  {'Name': 'Jean Gao',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'http://crystal.uta.edu/~gao',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Leonidas Fegaras',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'http://lambda.uta.edu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bob Weems',
#   'affiliation': 'University of Texas at Arlington',
#   'homepage': 'http://ranger.uta.edu/~weems',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'E. Allen Emerson',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'http://www.cs.utexas.edu/~emerson',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Don Fussell',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'http://www.cs.utexas.edu/users/fussell',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'C. Greg Plaxton',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'https://www.cs.utexas.edu/users/plaxton',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Vijay Chidambaram',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'http://www.cs.utexas.edu/~vijay',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'J Strother Moore',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'https://www.cs.utexas.edu/users/moore',
#   'scholar-id': '91fyr68AAAAJ',
#   'citations': '14873',
#   'h-index': '47'},
#  {'Name': 'Dan Miranker',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'https://www.cs.utexas.edu/~miranker',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Alan Cline',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'https://www.cs.utexas.edu/directory/alan-cline',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Eunsol Choi',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'https://homes.cs.washington.edu/~eunsol',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Jayadev Misra',
#   'affiliation': 'University of Texas at Austin',
#   'homepage': 'http://www.cs.utexas.edu/~misra',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ovidiu Daescu',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/~daescu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andras Farago',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/~farago',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ivan Hal Sudborough',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'https://explorer.utdallas.edu/editprofile.php?pid=13187',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Neeraj Mittal',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'https://www.utdallas.edu/~neerajm',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Balaji Raghavachari',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'https://www.utdallas.edu/~rbk',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Yvo Desmedt',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/~Yvo.Desmedt',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Shiyi Wei',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://utdallas.edu/~swei',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'R. Chandrasekaran',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'https://www.utdallas.edu/~chandra',
#   'scholar-id': 'AkvAUzkAAAAJ',
#   'citations': '9091',
#   'h-index': '49'},
#  {'Name': 'Yang Liu',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.hlt.utdallas.edu/~yangl',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Paul A. Fishwick',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/atec/fishwick',
#   'scholar-id': '-GT5PAkAAAAJ',
#   'citations': '8631',
#   'h-index': '45'},
#  {'Name': 'S. Q. Zheng',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/~sizheng',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Rym Mili',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/~rmili',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Sanda M. Harabagiu',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/~sanda',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Kevin W. Hamlen',
#   'affiliation': 'University of Texas at Dallas',
#   'homepage': 'http://www.utdallas.edu/~hamlen',
#   'scholar-id': 'Q2Fd_XYAAAAJ',
#   'citations': '4020',
#   'h-index': '31'},
#  {'Name': 'Farokh B. Bastani',
# ...
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Linh Anh Nguyen',
#   'affiliation': 'University of Warsaw',
#   'homepage': 'http://www.mimuw.edu.pl/~nguyen',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Marcin Peczarski',
#   'affiliation': 'University of Warsaw',
#   'homepage': 'http://www.mimuw.edu.pl/~marpe',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andrzej Janusz',
#   'affiliation': 'University of Warsaw',
#   'homepage': 'https://ml.linkedin.com/in/andrzej-janusz-bb693a33',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Anna Zych',
#   'affiliation': 'University of Warsaw',
#   'homepage': 'http://informatorects.uw.edu.pl/en/courses/view?prz_kod=1000-712ASD',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Jan Madey',
#   'affiliation': 'University of Warsaw',
#   'homepage': 'http://www.eunis.org/organization/jan-madey-bio',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Jane E. Sinclair',
#   'affiliation': 'University of Warwick',
#   'homepage': 'https://warwick.ac.uk/fac/sci/dcs/people/jane_sinclair',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Matthew Leeke',
#   'affiliation': 'University of Warwick',
#   'homepage': 'https://warwick.ac.uk/fac/sci/dcs/people/matthew_leeke',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Matthias Englert',
#   'affiliation': 'University of Warwick',
#   'homepage': 'https://warwick.ac.uk/fac/sci/dcs/people/matthias_englert',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Dmitry Chistikov',
#   'affiliation': 'University of Warwick',
#   'homepage': 'https://warwick.ac.uk/fac/sci/dcs/people/dmitry_chistikov',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Alan Borning',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://www.cs.washington.edu/people/faculty/borning',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Tanushree Mitra',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://faculty.washington.edu/tmitra',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Sewoong Oh',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://swoh.web.engr.illinois.edu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Michael B. Taylor',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://cseweb.ucsd.edu/~mbtaylor',
#   'scholar-id': 'H75ld_gAAAAJ',
#   'citations': '170',
#   'h-index': '2'},
#  {'Name': 'Steve Tanimoto',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://www.cs.washington.edu/people/faculty/tanimoto',
#   'scholar-id': 'OeULb38AAAAJ',
#   'citations': '7509',
#   'h-index': '35'},
#  {'Name': 'Ranjay Krishna',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://www.ranjaykrishna.com/index.html',
#   'scholar-id': 'IcqahyAAAAAJ',
#   'citations': '7012',
#   'h-index': '21'},
#  {'Name': 'Martin Tompa',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://www.cs.washington.edu/people/faculty/tompa',
#   'scholar-id': '0dLrHcQAAAAJ',
#   'citations': '9722',
#   'h-index': '40'},
#  {'Name': 'Linda G. Shapiro',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://cs.washington.edu/homes/shapiro',
#   'scholar-id': 'nBwaXUsAAAAJ',
#   'citations': '29108',
#   'h-index': '59'},
#  {'Name': 'Gary Hsieh',
#   'affiliation': 'University of Washington',
#   'homepage': 'http://faculty.washington.edu/garyhs',
#   'scholar-id': '-hwb_2kAAAAJ',
#   'citations': '3489',
#   'h-index': '29'},
#  {'Name': 'Adriana Schulz',
#   'affiliation': 'University of Washington',
#   'homepage': 'https://homes.cs.washington.edu/~adriana',
#   'scholar-id': 'q_krEZgAAAAJ',
#   'citations': '577',
#   'h-index': '12'},
#  {'Name': 'Shyam Gollakota',
#   'affiliation': 'University of Washington',
#   'homepage': 'https://homes.cs.washington.edu/~gshyam',
#   'scholar-id': 'w_HJY2MAAAAJ',
#   'citations': '12404',
#   'h-index': '43'},
#  {'Name': 'John Zahorjan',
#   'affiliation': 'University of Washington',
#   'homepage': 'https://homes.cs.washington.edu/~zahorjan',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Leilani Battle',
#   'affiliation': 'University of Washington',
#   'homepage': 'https://homes.cs.washington.edu/~leibatt/bio.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Meng Xu',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~m285xu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Richard Mann',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~mannr',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Lukasz Golab',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://www.engineering.uwaterloo.ca/~lgolab',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Lila Kari',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/about/people/lila',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Chaitanya Swamy',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'http://www.math.uwaterloo.ca/~cswamy',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Gladimir Baranoski',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'http://www.npsg.uwaterloo.ca/people/gladimir',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Prabhakar Ragde',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~plragde',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ian Goldberg',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~iang',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ian Munro',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~imunro',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Peter A. Buhr',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'http://plg.uwaterloo.ca/~pabuhr',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Eric Blais',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~eblais',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Andrew C. Doxey',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'http://doxey.uwaterloo.ca',
#   'scholar-id': 'iUQqmUYAAAAJ',
#   'citations': '2340',
#   'h-index': '30'},
#  {'Name': 'Grant E. Weddell',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/faculty-staff/contacts/grant-weddell',
#   'scholar-id': 'QjSgyEsAAAAJ',
#   'citations': '1450',
#   'h-index': '20'},
#  {'Name': 'Sebastian Fischmeister',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://uwaterloo.ca/embedded-software-group/people-profiles/sebastian-fischmeister',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'James R. Wallace',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://uwaterloo.ca/human-computer-interaction-health-lab',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Justin W. L. Wan',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~jwlwan',
#   'scholar-id': 'jaJlXfwAAAAJ',
#   'citations': '1396',
#   'h-index': '19'},
#  {'Name': 'Khuzaima Daudjee',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'http://cs.uwaterloo.ca/~kdaudjee',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Mark Giesbrecht',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://uwaterloo.ca/~mwg',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Daniel G. Brown',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~browndg',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ian McKillop',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://uwaterloo.ca/public-health-and-health-systems/people-profiles/ian-mckillop',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Arne Storjohann',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~astorjoh',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Stephen Mann',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'http://www.cgl.uwaterloo.ca/smann',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Richard J. Trefler',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/~trefler',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Shalev Ben-David',
#   'affiliation': 'University of Waterloo',
#   'homepage': 'https://cs.uwaterloo.ca/about/people/shalev-ben-david',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Cara K. MacNish',
#   'affiliation': 'University of Western Australia',
#   'homepage': 'http://www.web.uwa.edu.au/people/cara.macnish',
#   'scholar-id': 'nqqUzUYAAAAJ',
#   'citations': '1734',
#   'h-index': '15'},
#  {'Name': 'Lyndon While',
#   'affiliation': 'University of Western Australia',
#   'homepage': 'http://uwa.edu.au/people/lyndon.while',
#   'scholar-id': 'XcUewvwAAAAJ',
#   'citations': '5118',
#   'h-index': '24'},
#  {'Name': 'Christof Hübner',
#   'affiliation': 'University of Western Australia',
#   'homepage': 'http://www.ecm.uwa.edu.au/research/engineering-communities-environment/energy-saving-houses/investigatorsandpartners',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Bruce S. Gardiner',
#   'affiliation': 'University of Western Australia',
#   'homepage': 'http://biomed.csse.uwa.edu.au/people_bruce.php',
#   'scholar-id': 'EhgH1t8AAAAJ',
#   'citations': '4070',
#   'h-index': '36'},
#  {'Name': 'Scott. D. Goodwin',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1036/dr-scott-goodwin',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Pooya Moradian Zadeh',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1047/dr-pooya-moradian-zadeh',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Alioune Ngom',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1061/dr-alioune-ngom',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Robert D. Kent',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1037/dr-robert-kent',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Yung H. Tsin',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1025/dr-yung-h-tsin',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Xiaobu Yuan',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1032/dr-xiaobu-yuan',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Boubakeur Boufama',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1059/dr-boubakeur-boufama',
#   'scholar-id': '-xk1C0cAAAAJ',
#   'citations': '1610',
#   'h-index': '19'},
#  {'Name': 'Sherif Saad Ahmed',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1026/dr-sherif-saad-ahmed',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Xiao Jun Chen',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1058/dr-jessica-chen',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Ziad Kobti',
#   'affiliation': 'University of Windsor',
#   'homepage': 'http://www.uwindsor.ca/science/computerscience/1060/dr-ziad',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Dieter van Melkebeek',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://pages.cs.wisc.edu/~dieter',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Jelena Diakonikolas',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://www.jelena-diakonikolas.com',
#   'scholar-id': 'J8ixfu8AAAAJ',
#   'citations': '833',
#   'h-index': '17'},
#  {'Name': 'Eric Bach',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://pages.cs.wisc.edu/~bach/bach.html',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Guri Sohi',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://pages.cs.wisc.edu/~sohi',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Garvesh Raskutti',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://pages.cs.wisc.edu/~raskutti',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Po-Ling Loh',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://homepages.cae.wisc.edu/~loh',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Colin N. Dewey',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'https://www.biostat.wisc.edu/~cdewey',
#   'scholar-id': '0ZMkdbYAAAAJ',
#   'citations': '44738',
#   'h-index': '34'},
#  {'Name': 'Ramya Korlakai Vinayak',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'https://ramyakv.github.io',
#   'scholar-id': '-dDKMgoAAAAJ',
#   'citations': '160',
#   'h-index': '6'},
#  {'Name': 'Yea-Seul Kim',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'https://pages.cs.wisc.edu/~yeaseulkim',
#   'scholar-id': 'I6_09PIAAAAJ',
#   'citations': '503',
#   'h-index': '13'},
#  {'Name': 'Jignesh M. Patel',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://pages.cs.wisc.edu/~jignesh',
#   'scholar-id': 'tOjfnFMAAAAJ',
#   'citations': '20242',
#   'h-index': '66'},
#  {'Name': 'Dan Negrut',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'https://sbel.wisc.edu/negrut-dan',
#   'scholar-id': 'dTrsl-gAAAAJ',
#   'citations': '3307',
#   'h-index': '33'},
#  {'Name': 'James R. Luedtke',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'https://homepages.cae.wisc.edu/~luedtkej',
#   'scholar-id': 'f-GQKN0AAAAJ',
#   'citations': '3379',
#   'h-index': '26'},
#  {'Name': 'Deborah Joseph',
#   'affiliation': 'University of Wisconsin - Madison',
#   'homepage': 'http://www.cs.wisc.edu/people/joseph',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Mukul Goyal',
#   'affiliation': 'University of Wisconsin - Milwaukee',
#   'homepage': 'https://uwm.edu/engineering/people/goyal-ph-d-mukul',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None},
#  {'Name': 'Susan McRoy',
#   'affiliation': 'University of Wisconsin - Milwaukee',
#   'homepage': 'https://uwm.edu/engineering/people/mcroy-ph-d-susan',
#   'scholar-id': 'cIxN_SIAAAAJ',
#   'citations': '1886',
#   'h-index': '21'},
#  {'Name': 'Amol Dattatraya Mali',
#   'affiliation': 'University of Wisconsin - Milwaukee',
#   'homepage': 'http://www.cs.uwm.edu/faculty/mali/conferences/distributed-ictai.pdf',
#   'scholar-id': '9aqKSJ0AAAAJ',
#   'citations': '566',
#   'h-index': '11'},
#  {'Name': 'Tian Zhao',
#   'affiliation': 'University of Wisconsin - Milwaukee',
#   'homepage': 'http://jiangxi.cs.uwm.edu',
#   'scholar-id': '65p2anoAAAAJ',
#   'citations': '1344',
#   'h-index': '23'},
#  {'Name': 'Guangwu Xu',
#   'affiliation': 'University of Wisconsin - Milwaukee',
#   'homepage': 'https://uwm.edu/engineering/people/xu-ph-d-guangwu',
#   'scholar-id': None,
#   'citations': None,
#   'h-index': None}]

# %%
data.loc[data['name'] == 'Kamal Deep Singh']
# Out:
#                    name             affiliation  \
# 19560  Kamal Deep Singh  Université Jean Monnet
#
#                                                 homepage    scholar_id  \
# 19560  https://laboratoirehubertcurien.univ-st-etienn...  mDLQC0EAAAAJ
#
#        citations  h-index
# 19560        NaN      NaN

# %%
print(len(professors))
df = pd.DataFrame(professors)
df.to_csv("cleaned_prof_data_v5_39.csv")
# Out:
# 287

# %%
data.iloc[19384]
# Out:
# name                                               Ichiro Suzuki
# affiliation                  University of Wisconsin - Milwaukee
# homepage       https://uwm.edu/engineering/people/suzuki-ph-d...
# scholar_id                                         NOSCHOLARPAGE
# citations                                                    NaN
# h-index                                                      NaN
# Name: 19384, dtype: object

# %%
data.tail()
# Out:
#                name         affiliation  \
# 20644  Ali C. Begen  Özyeğin University
# 20645   Erhan Öztop  Özyeğin University
# 20646  Yasar Safkan  Özyeğin University
# 20647   Hasan Sözer  Özyeğin University
# 20648    Emre Sefer  Özyeğin University
#
#                                                 homepage     scholar_id  \
# 20644                              https://ali.begen.net   ZIZWsXoAAAAJ
# 20645  https://robotics.ozyegin.edu.tr/members/erhan-...   A8YEQMMAAAAJ
# 20646   https://cs.ozyegin.edu.tr/en/faculty/yasarsafkan  NOSCHOLARPAGE
# 20647              https://faculty.ozyegin.edu.tr/hsozer   L3FuUX0AAAAJ
# 20648                           http://www.emresefer.com   W5qWthcAAAAJ
#
#        citations  h-index
# 20644     5964.0     34.0
# 20645     3702.0     28.0
# 20646        NaN      NaN
# 20647      847.0     16.0
# 20648      253.0     10.0
